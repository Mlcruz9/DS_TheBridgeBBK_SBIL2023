# %% [markdown]
# # Ejercicios de Seaborn

# %% [markdown]
# ### 1. Importa pandas, pyplot y seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 2. Lee 'Pokemon.csv', lee la primera columna del csv como índice del DataFrame

# %%
pokemon_df = pd.read_csv('data/Pokemon.csv', index_col= 0, encoding= 'ISO-8859-1')
pokemon_df.head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %%
pokemon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 151 entries, 1 to 151
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       151 non-null    object
#  1   Type 1     151 non-null    object
#  2   Type 2     67 non-null     object
#  3   Total      151 non-null    int64
#  4   HP         151 non-null    int64
#  5   Attack     151 non-null    int64
#  6   Defense    151 non-null    int64
#  7   Sp. Atk    151 non-null    int64
#  8   Sp. Def    151 non-null    int64
#  9   Speed      151 non-null    int64
#  10  Stage      151 non-null    int64
#  11  Legendary  151 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 14.3+ KB

# %%
pokemon_df['Type 2'] = np.where(pokemon_df['Type 2'].isna(), 'No tiene', pokemon_df['Type 2'])

# %%
pokemon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 151 entries, 1 to 151
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       151 non-null    object
#  1   Type 1     151 non-null    object
#  2   Type 2     151 non-null    object
#  3   Total      151 non-null    int64
#  4   HP         151 non-null    int64
#  5   Attack     151 non-null    int64
#  6   Defense    151 non-null    int64
#  7   Sp. Atk    151 non-null    int64
#  8   Sp. Def    151 non-null    int64
#  9   Speed      151 non-null    int64
#  10  Stage      151 non-null    int64
#  11  Legendary  151 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 14.3+ KB

# %% [markdown]
# ### 3. Mira las primeras filas del dataset para hacerte una idea de los datos cargados

# %%
pokemon_df.head()
# Out:
#          Name Type 1    Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass    Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass    Poison    405  60      62       63       80       80
# 3    Venusaur  Grass    Poison    525  80      82       83      100      100
# 4  Charmander   Fire  No tiene    309  39      52       43       60       50
# 5  Charmeleon   Fire  No tiene    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %% [markdown]
# ### 4. Haz un scatter plot con lmplot(), que es el método que pinta una regresión lineal. Pasa el DataFrame como argumento del método en el parámetro llamado data

# %%
sns.lmplot(data = pokemon_df, x = 'Attack', y = 'Defense')
# Out:
# c:\Users\misla\.pyenv\pyenv-win\versions\3.9.7\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### 5. No queremos ver la línea recta de la regresión lineal. Prueba a añadir fit_reg a falso

# %%
sns.lmplot(data = pokemon_df, x = 'Attack', y = 'Defense', fit_reg= False)
# Out:
# c:\Users\misla\.pyenv\pyenv-win\versions\3.9.7\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### 6. Vamos a decir qué variable (columna del DataFrame) codifica los colores (hue). Que el hue sea el Stage

# %%
sns.lmplot(data = pokemon_df, x = 'Attack', y = 'Defense', fit_reg= False, hue = 'Stage')
# Out:
# c:\Users\misla\.pyenv\pyenv-win\versions\3.9.7\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### 7. Limita el eje x entre 20 y 100

# %%
sns.lmplot(data = pokemon_df, x = 'Attack', y = 'Defense', fit_reg= False, hue = 'Stage')
plt.xlim(20, 100)
# Out:
# c:\Users\misla\.pyenv\pyenv-win\versions\3.9.7\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# (20.0, 100.0)

# %% [markdown]
# ### 8. Dibuja un diagrama de cajas con el dataframe

# %%
pokemon_df['Legendary']
# Out:
# #
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 147    False
# 148    False
# 149    False
# 150     True
# 151    False
# Name: Legendary, Length: 151, dtype: bool

# %%
sns.boxplot(pokemon_df)
# Out:
# <Axes: >

# %% [markdown]
# ### 9. No nos interesan las columnas Total, Stage ni Legendary. Bórralos del DataFrame y vuelve a dibujar el diagrama de cajas

# %%
pokemon_df
# Out:
#            Name   Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 1     Bulbasaur    Grass    Poison    318   45      49       49       65
# 2       Ivysaur    Grass    Poison    405   60      62       63       80
# 3      Venusaur    Grass    Poison    525   80      82       83      100
# 4    Charmander     Fire  No tiene    309   39      52       43       60
# 5    Charmeleon     Fire  No tiene    405   58      64       58       80
# ..          ...      ...       ...    ...  ...     ...      ...      ...
# 147     Dratini   Dragon  No tiene    300   41      64       45       50
# 148   Dragonair   Dragon  No tiene    420   61      84       65       70
# 149   Dragonite   Dragon    Flying    600   91     134       95      100
# 150      Mewtwo  Psychic  No tiene    680  106     110       90      154
# 151         Mew  Psychic  No tiene    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# #
# 1         65     45      1      False
# 2         80     60      2      False
# 3        100     80      3      False
# 4         50     65      1      False
# 5         65     80      2      False
# ..       ...    ...    ...        ...
# 147       50     50      1      False
# 148       70     70      2      False
# 149      100     80      3      False
# 150       90    130      1       True
# 151      100    100      1      False
#
# [151 rows x 12 columns]

# %%
sns.boxplot(pokemon_df.drop(columns= ['Total', 'Legendary', 'Stage']))
# Out:
# <Axes: >

# %% [markdown]
# ### 10. Mira cuántos 'Type 1' diferentes hay en el DataFrame

# %%
pokemon_df['Type 1'].nunique()
# Out:
# 15

# %%
pokemon_df['Type 1'].value_counts()
# Out:
# Type 1
# Water       28
# Normal      22
# Poison      14
# Grass       12
# Fire        12
# Bug         12
# Electric     9
# Rock         9
# Ground       8
# Psychic      8
# Fighting     7
# Ghost        3
# Dragon       3
# Fairy        2
# Ice          2
# Name: count, dtype: int64

# %%
conteo = pokemon_df['Type 1'].value_counts(ascending=False)

plt.figure(figsize=(10,5))
plt.hlines(y=conteo.index,
           xmin=0,
           xmax=conteo,
           color='skyblue')
plt.plot(conteo, conteo.index, "o");

# %% [markdown]
# ### 11. Quédate del Dataframe solo con los 'Type 1' iguales a 'Grass', 'Fire' o 'Water' y llamalo df_gfw

# %%
df_gfw = pokemon_df[pokemon_df['Type 1'].isin(['Grass', 'Fire', 'Water'])]

# %%
df_gfw
# Out:
#            Name Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 1     Bulbasaur  Grass    Poison    318   45      49       49       65
# 2       Ivysaur  Grass    Poison    405   60      62       63       80
# 3      Venusaur  Grass    Poison    525   80      82       83      100
# 4    Charmander   Fire  No tiene    309   39      52       43       60
# 5    Charmeleon   Fire  No tiene    405   58      64       58       80
# 6     Charizard   Fire    Flying    534   78      84       78      109
# 7      Squirtle  Water  No tiene    314   44      48       65       50
# 8     Wartortle  Water  No tiene    405   59      63       80       65
# 9     Blastoise  Water  No tiene    530   79      83      100       85
# 37       Vulpix   Fire  No tiene    299   38      41       40       50
# 38    Ninetales   Fire  No tiene    505   73      76       75       81
# 43       Oddish  Grass    Poison    320   45      50       55       75
# 44        Gloom  Grass    Poison    395   60      65       70       85
# 45    Vileplume  Grass    Poison    490   75      80       85      110
# 54      Psyduck  Water  No tiene    320   50      52       48       65
# 55      Golduck  Water  No tiene    500   80      82       78       95
# 58    Growlithe   Fire  No tiene    350   55      70       45       70
# 59     Arcanine   Fire  No tiene    555   90     110       80      100
# 60      Poliwag  Water  No tiene    300   40      50       40       40
# 61    Poliwhirl  Water  No tiene    385   65      65       65       50
# 62    Poliwrath  Water  Fighting    510   90      95       95       70
# 69   Bellsprout  Grass    Poison    300   50      75       35       70
# 70   Weepinbell  Grass    Poison    390   65      90       50       85
# 71   Victreebel  Grass    Poison    490   80     105       65      100
# 72    Tentacool  Water    Poison    335   40      40       35       50
# 73   Tentacruel  Water    Poison    515   80      70       65       80
# 77       Ponyta   Fire  No tiene    410   50      85       55       65
# 78     Rapidash   Fire  No tiene    500   65     100       70       80
# 79     Slowpoke  Water   Psychic    315   90      65       65       40
# 80      Slowbro  Water   Psychic    490   95      75      110      100
# 86         Seel  Water  No tiene    325   65      45       55       45
# 87      Dewgong  Water       Ice    475   90      70       80       70
# 90     Shellder  Water  No tiene    305   30      65      100       45
# 91     Cloyster  Water       Ice    525   50      95      180       85
# 98       Krabby  Water  No tiene    325   30     105       90       25
# 99      Kingler  Water  No tiene    475   55     130      115       50
# 102   Exeggcute  Grass   Psychic    325   60      40       80       60
# 103   Exeggutor  Grass   Psychic    520   95      95       85      125
# 114     Tangela  Grass  No tiene    435   65      55      115      100
# 116      Horsea  Water  No tiene    295   30      40       70       70
# 117      Seadra  Water  No tiene    440   55      65       95       95
# 118     Goldeen  Water  No tiene    320   45      67       60       35
# 119     Seaking  Water  No tiene    450   80      92       65       65
# 120      Staryu  Water  No tiene    340   30      45       55       70
# 121     Starmie  Water   Psychic    520   60      75       85      100
# 126      Magmar   Fire  No tiene    495   65      95       57      100
# 129    Magikarp  Water  No tiene    200   20      10       55       15
# 130    Gyarados  Water    Flying    540   95     125       79       60
# 131      Lapras  Water       Ice    535  130      85       80       85
# 134    Vaporeon  Water  No tiene    525  130      65       60      110
# 136     Flareon   Fire  No tiene    525   65     130       60       95
# 146     Moltres   Fire    Flying    580   90     100       90      125
#
#      Sp. Def  Speed  Stage  Legendary
# #
# 1         65     45      1      False
# 2         80     60      2      False
# 3        100     80      3      False
# 4         50     65      1      False
# 5         65     80      2      False
# 6         85    100      3      False
# 7         64     43      1      False
# 8         80     58      2      False
# 9        105     78      3      False
# 37        65     65      1      False
# 38       100    100      2      False
# 43        65     30      1      False
# 44        75     40      2      False
# 45        90     50      3      False
# 54        50     55      1      False
# 55        80     85      2      False
# 58        50     60      1      False
# 59        80     95      2      False
# 60        40     90      1      False
# 61        50     90      2      False
# 62        90     70      3      False
# 69        30     40      1      False
# 70        45     55      2      False
# 71        70     70      3      False
# 72       100     70      1      False
# 73       120    100      2      False
# 77        65     90      1      False
# 78        80    105      2      False
# 79        40     15      1      False
# 80        80     30      2      False
# 86        70     45      1      False
# 87        95     70      2      False
# 90        25     40      1      False
# 91        45     70      2      False
# 98        25     50      1      False
# 99        50     75      2      False
# 102       45     40      1      False
# 103       65     55      2      False
# 114       40     60      1      False
# 116       25     60      1      False
# 117       45     85      2      False
# 118       50     63      1      False
# 119       80     68      2      False
# 120       55     85      1      False
# 121       85    115      2      False
# 126       85     93      1      False
# 129       20     80      1      False
# 130      100     81      2      False
# 131       95     60      1      False
# 134       95     65      2      False
# 136      110     65      2      False
# 146       85     90      1       True

# %% [markdown]
# ### 12. Usa un estilo 'whitegrid'

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ### 13. Pinta diagramas de violín con el df_gfw

# %%
sns.violinplot(df_gfw);

# %% [markdown]
# ### 14. Escribe una lista de colores con valores '#78C850', '#F08030',  '#6890F0'

# %%
colores = ['#78C850', '#F08030',  '#6890F0']

# %% [markdown]
# ### 15. Pinta de nuevo los diagramas de violín añadiendo esos colores en la paleta (palette)

# %%
sns.violinplot(df_gfw, palette= colores);

# %% [markdown]
# ### 16. Con el diagrama de violín vemos la forma de la distribución, pero no sabemos si Grass tiene muchos puntos y Fire tiene muy pocos.Para ver esto, usamos el swarmplot. Pinta el último diagrama de violines pero con un swarmplot en lugar de un violin

# %%
sns.violinplot(df_gfw, palette= colores)
sns.swarmplot(df_gfw, color = 'k');
# Out:
# c:\Users\misla\.pyenv\pyenv-win\versions\3.9.7\lib\site-packages\seaborn\categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:k'` for same effect.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### 17. Queremos ver los violines a la vez que los swarm, los podemos pintar juntos. Elimina los diagramas de caja dentro de los violines con el parámetro inner = None y pon una saturación de 0.9. Pon un título con pyplot (como siempre)

# %%
sns.violinplot(df_gfw, palette= colores, inner= None, saturation= 0.9)
sns.swarmplot(df_gfw, color = 'k')
plt.title('Pokemon Stats');
# Out:
# c:\Users\misla\.pyenv\pyenv-win\versions\3.9.7\lib\site-packages\seaborn\categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:k'` for same effect.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### 18. Veamos la función melt() de pandas. Melt toma los valores de varias columnas y los junta todos en una misma columna nueva.
#
# ### Dado un DataFrame, melt recibe varios parámetros:
# * qué columnas del DataFrame se quedan igual
# * qué nombres de columnas del dataframe pasan a ser una columna nueva
# * cómo queremos llamar esas nuevas columnas
#
# #### Primero recuerda el Dataframe df_gfw con las primeras 5 filas

# %%
df_gfw.head()
# Out:
#          Name Type 1    Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# #
# 1   Bulbasaur  Grass    Poison  45      49       49       65       65     45
# 2     Ivysaur  Grass    Poison  60      62       63       80       80     60
# 3    Venusaur  Grass    Poison  80      82       83      100      100     80
# 4  Charmander   Fire  No tiene  39      52       43       60       50     65
# 5  Charmeleon   Fire  No tiene  58      64       58       80       65     80

# %% [markdown]
# ### 19. Queremos dejar igual las variables 'Name' y 'Type 1'
# #### Queremos añadir una columa nueva cuyos valores sean las columnas que queremos apilar y que se llame 'New Column'
# ##### Escribimos df_gfw.melt(id_vars=['Name', 'Type 1'], value_vars=[...], var_name='New Column')

# %%
df_gfw.columns[3:]
# Out:
# Index(['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed'], dtype='object')

# %%
df_melted = df_gfw.melt(id_vars=['Name', 'Type 1'], value_vars=df_gfw.columns[3:], var_name='New Column')

# %%
df_gfw
# Out:
#            Name Type 1    Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1     Bulbasaur  Grass    Poison   45      49       49       65       65
# 2       Ivysaur  Grass    Poison   60      62       63       80       80
# 3      Venusaur  Grass    Poison   80      82       83      100      100
# 4    Charmander   Fire  No tiene   39      52       43       60       50
# 5    Charmeleon   Fire  No tiene   58      64       58       80       65
# 6     Charizard   Fire    Flying   78      84       78      109       85
# 7      Squirtle  Water  No tiene   44      48       65       50       64
# 8     Wartortle  Water  No tiene   59      63       80       65       80
# 9     Blastoise  Water  No tiene   79      83      100       85      105
# 37       Vulpix   Fire  No tiene   38      41       40       50       65
# 38    Ninetales   Fire  No tiene   73      76       75       81      100
# 43       Oddish  Grass    Poison   45      50       55       75       65
# 44        Gloom  Grass    Poison   60      65       70       85       75
# 45    Vileplume  Grass    Poison   75      80       85      110       90
# 54      Psyduck  Water  No tiene   50      52       48       65       50
# 55      Golduck  Water  No tiene   80      82       78       95       80
# 58    Growlithe   Fire  No tiene   55      70       45       70       50
# 59     Arcanine   Fire  No tiene   90     110       80      100       80
# 60      Poliwag  Water  No tiene   40      50       40       40       40
# 61    Poliwhirl  Water  No tiene   65      65       65       50       50
# 62    Poliwrath  Water  Fighting   90      95       95       70       90
# 69   Bellsprout  Grass    Poison   50      75       35       70       30
# 70   Weepinbell  Grass    Poison   65      90       50       85       45
# 71   Victreebel  Grass    Poison   80     105       65      100       70
# 72    Tentacool  Water    Poison   40      40       35       50      100
# 73   Tentacruel  Water    Poison   80      70       65       80      120
# 77       Ponyta   Fire  No tiene   50      85       55       65       65
# 78     Rapidash   Fire  No tiene   65     100       70       80       80
# 79     Slowpoke  Water   Psychic   90      65       65       40       40
# 80      Slowbro  Water   Psychic   95      75      110      100       80
# 86         Seel  Water  No tiene   65      45       55       45       70
# 87      Dewgong  Water       Ice   90      70       80       70       95
# 90     Shellder  Water  No tiene   30      65      100       45       25
# 91     Cloyster  Water       Ice   50      95      180       85       45
# 98       Krabby  Water  No tiene   30     105       90       25       25
# 99      Kingler  Water  No tiene   55     130      115       50       50
# 102   Exeggcute  Grass   Psychic   60      40       80       60       45
# 103   Exeggutor  Grass   Psychic   95      95       85      125       65
# 114     Tangela  Grass  No tiene   65      55      115      100       40
# 116      Horsea  Water  No tiene   30      40       70       70       25
# 117      Seadra  Water  No tiene   55      65       95       95       45
# 118     Goldeen  Water  No tiene   45      67       60       35       50
# 119     Seaking  Water  No tiene   80      92       65       65       80
# 120      Staryu  Water  No tiene   30      45       55       70       55
# 121     Starmie  Water   Psychic   60      75       85      100       85
# 126      Magmar   Fire  No tiene   65      95       57      100       85
# 129    Magikarp  Water  No tiene   20      10       55       15       20
# 130    Gyarados  Water    Flying   95     125       79       60      100
# 131      Lapras  Water       Ice  130      85       80       85       95
# 134    Vaporeon  Water  No tiene  130      65       60      110       95
# 136     Flareon   Fire  No tiene   65     130       60       95      110
# 146     Moltres   Fire    Flying   90     100       90      125       85
#
#      Speed
# #
# 1       45
# 2       60
# 3       80
# 4       65
# 5       80
# 6      100
# 7       43
# 8       58
# 9       78
# 37      65
# 38     100
# 43      30
# 44      40
# 45      50
# 54      55
# 55      85
# 58      60
# 59      95
# 60      90
# 61      90
# 62      70
# 69      40
# 70      55
# 71      70
# 72      70
# 73     100
# 77      90
# 78     105
# 79      15
# 80      30
# 86      45
# 87      70
# 90      40
# 91      70
# 98      50
# 99      75
# 102     40
# 103     55
# 114     60
# 116     60
# 117     85
# 118     63
# 119     68
# 120     85
# 121    115
# 126     93
# 129     80
# 130     81
# 131     60
# 134     65
# 136     65
# 146     90

# %%
df_melted
# Out:
#            Name Type 1 New Column  value
# 0     Bulbasaur  Grass         HP     45
# 1       Ivysaur  Grass         HP     60
# 2      Venusaur  Grass         HP     80
# 3    Charmander   Fire         HP     39
# 4    Charmeleon   Fire         HP     58
# ..          ...    ...        ...    ...
# 307    Gyarados  Water      Speed     81
# 308      Lapras  Water      Speed     60
# 309    Vaporeon  Water      Speed     65
# 310     Flareon   Fire      Speed     65
# 311     Moltres   Fire      Speed     90
#
# [312 rows x 4 columns]

# %% [markdown]
# #### 20. Pintamos el swarmplot con el melted y entendemos la información -- -- sns.swarmplot(data = df_gfw_melted, x= 'New Column', y= 'value', hue = 'New Column');

# %%
sns.swarmplot(data = df_melted, x= 'New Column', y= 'value', hue = 'New Column')
# Out:
# <Axes: xlabel='New Column', ylabel='value'>

# %% [markdown]
# ### 21. Basándote en el gráfico anterior, define el tamaño de la figura en (10,6) (usa plt).
#
# * En el swarmplot añade el argumento dodge a True y usa la anterior paleta de colores Pokemon
# * Dodge en inglés es "esquivar", ¿qué diferencia ves?
# * Usando plt
# * fija el límite del eje Y entre 0 y 200
# * fija la leyenda con bbox_to_anchor arriba a la izquierda. Pista: (x, y, width, height)

# %%
plt.figure(figsize= (10, 6))
sns.swarmplot(data = df_melted, x= 'New Column', y= 'value', hue = 'Type 1', dodge= True, palette= colores)
plt.ylim(0, 200)
plt.legend(loc = 'upper left');

# %% [markdown]
# #### Observa que incluso usando Seaborn, usamos Pyplot para trabajar con los ejes, la leyenda y el tamaño. Lo importante es que Seaborn y Pyplot conviven bien juntos

# %% [markdown]
# ### 22. Mapas de calor
# * Calcula las correlaciones del primer DataFrame original df
# * Pista: las correlaciones se calculan con el método corr()
# * Recuerda: las correlaciones miden entre dos variables, si varío una, cuánto me varía la otra (cómo están de relacionadas)

# %%
pokemon_df.corr(numeric_only= True)
# Out:
#               Total        HP    Attack   Defense   Sp. Atk   Sp. Def  \
# Total      1.000000  0.576591  0.670939  0.508694  0.680745  0.774383
# HP         0.576591  1.000000  0.306768  0.119782  0.236649  0.490978
# Attack     0.670939  0.306768  1.000000  0.491965  0.146312  0.369069
# Defense    0.508694  0.119782  0.491965  1.000000  0.187569  0.139912
# Sp. Atk    0.680745  0.236649  0.146312  0.187569  1.000000  0.522907
# Sp. Def    0.774383  0.490978  0.369069  0.139912  0.522907  1.000000
# Speed      0.506950 -0.040939  0.194701 -0.053252  0.411516  0.392656
# Stage      0.504224  0.249207  0.361321  0.270861  0.391712  0.358308
# Legendary  0.328412  0.172441  0.147486  0.141576  0.334159  0.215314
#
#               Speed     Stage  Legendary
# Total      0.506950  0.504224   0.328412
# HP        -0.040939  0.249207   0.172441
# Attack     0.194701  0.361321   0.147486
# Defense   -0.053252  0.270861   0.141576
# Sp. Atk    0.411516  0.391712   0.334159
# Sp. Def    0.392656  0.358308   0.215314
# Speed      1.000000  0.240042   0.199969
# Stage      0.240042  1.000000  -0.142508
# Legendary  0.199969 -0.142508   1.000000

# %% [markdown]
# - ¿la correlación entre qué valores se encuentra?
# - la autocorrelación es la correlación de una variable consigo misma, ¿qué aprecias?
# - Encuentra dos variables que veas que están fuertemente relacionadas según la correlación
# - Si tuvieras una matriz de correlación muy grande y te cobrasen por cada dato que lees, ¿qué harías?

# %%
sns.heatmap(pokemon_df.corr(numeric_only= True), annot= True);

# %% [markdown]
# ### 23. Pinta el histograma y la densidad de probabilidad del nivel de defensa usando el DataFrame original

# %%
sns.distplot(pokemon_df['Defense']);
# Out:
# C:\Users\misla\AppData\Local\Temp\ipykernel_11312\1472395116.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(pokemon_df['Defense']);

# %% [markdown]
# ### 24. Pinta un diagrama de barras de la columna 'Type 1' usando el DataFrame original
# * Usa un sns.countplot
# * Usa plt.xticks y gira las etiquetas

# %%
sns.countplot(data = pokemon_df, x = 'Type 1')
plt.xticks(rotation = 45);

# %% [markdown]
# ### 25. Usa catplot con el DataFrame original. Muestra el valor de Defense según el 'Type 1', muestra un subplot para legendarios y otro para no legendarios y divide los colores según el Type 2

# %%
grafica = sns.catplot(data = pokemon_df, x = 'Type 1', y = 'Defense', col= 'Legendary', hue= 'Type 2')
grafica.set_xticklabels(rotation = 45)
# Out:
# c:\Users\misla\.pyenv\pyenv-win\versions\3.9.7\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### 26. Muestra una función distribución de probabilidad con kdeplot (curvas de nivel) de la defensa respecto al ataque.  Di un bin 2D donde caigan muchos puntos (ataque, defensa).

# %%
sns.kdeplot(data = pokemon_df, x = 'Defense', y = 'Attack')
# Out:
# <Axes: xlabel='Defense', ylabel='Attack'>

# %% [markdown]
# ### 27. Pinta una distribución de probabilidad conjunta, pintando la defensa respecto al ataque del DataFrame original. Pista: jointplot()

# %%
sns.jointplot(data = pokemon_df, x = 'Defense', y = 'Attack', kind= 'hex')
