# %% [markdown]
# ![imagen](https://cdn.foodbeast.com/content/wp-content/uploads/2012/03/beer-print-01-selectism.jpg)
#
# # Ejercicio pandas estadistica
# Para este ejercicio se ha utilizado [un dataset de un concurso de kaggle](https://www.kaggle.com/nickhould/craft-cans), cuyo reto consiste en predecir el tipo de cerveza en función de sus características (nivel de alcohol, amargura, tamaño...).
#
# # Ejercicio 1
# Importa las librerias que consideres

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Ejercicio 2
# 1. Importa el dataset "datasets_beer.csv"
# 2. Imprime por pantalla los primeros registros.
# 3. ¿Cuáles son sus columnas?
# 4. ¿Qué dimensiones tiene el DataFrame?

# %%
beers = pd.read_csv('data/datasets_beers.csv')
beers.head()

# %%
beers.columns
# Out:
# Index(['Unnamed: 0', 'abv', 'ibu', 'id', 'name', 'style', 'brewery_id',
#        'ounces'],
#       dtype='object')

# %%
beers.shape
# Out:
# (2410, 8)

# %%
beers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2410 non-null   int64
#  1   abv         2348 non-null   float64
#  2   ibu         1405 non-null   float64
#  3   id          2410 non-null   int64
#  4   name        2410 non-null   object
#  5   style       2405 non-null   object
#  6   brewery_id  2410 non-null   int64
#  7   ounces      2410 non-null   float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 150.8+ KB

# %% [markdown]
# ## Ejercicio 3
# [Elimina la columna "Unnamed: 0"](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html)

# %%
beers.drop(columns='Unnamed: 0', inplace= True)

# %%
beers
# Out:
#         abv   ibu    id                  name                           style  \
# 0     0.050   NaN  1436              Pub Beer             American Pale Lager
# 1     0.066   NaN  2265           Devil's Cup         American Pale Ale (APA)
# 2     0.071   NaN  2264   Rise of the Phoenix                    American IPA
# 3     0.090   NaN  2263              Sinister  American Double / Imperial IPA
# 4     0.075   NaN  2262         Sex and Candy                    American IPA
# ...     ...   ...   ...                   ...                             ...
# 2405  0.067  45.0   928             Belgorado                     Belgian IPA
# 2406  0.052   NaN   807         Rail Yard Ale        American Amber / Red Ale
# 2407  0.055   NaN   620       B3K Black Lager                     Schwarzbier
# 2408  0.055  40.0   145   Silverback Pale Ale         American Pale Ale (APA)
# 2409  0.052   NaN    84  Rail Yard Ale (2009)        American Amber / Red Ale
#
#       brewery_id  ounces
# ...

# %% [markdown]
# ## Ejercicio 4
# ¿Cuántas filas y columnas tiene el dataset?

# %%
beers.shape
# Out:
# (2410, 7)

# %% [markdown]
# ## Ejercicio 5
# ¿De qué tipo son los datos?

# %%
beers.dtypes
# Out:
# abv           float64
# ibu           float64
# id              int64
# name           object
# style          object
# brewery_id      int64
# ounces        float64
# dtype: object

# %%
beers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   abv         2348 non-null   float64
#  1   ibu         1405 non-null   float64
#  2   id          2410 non-null   int64
#  3   name        2410 non-null   object
#  4   style       2405 non-null   object
#  5   brewery_id  2410 non-null   int64
#  6   ounces      2410 non-null   float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 131.9+ KB

# %% [markdown]
# ## Ejercicio 6
# Obtén en un nuevo DataFrame un resumen con las principales estadísticas de las columnas numéricas: mean, max, count, cuartiles...

# %%
beers.describe()
# Out:
#                abv          ibu           id   brewery_id       ounces
# count  2348.000000  1405.000000  2410.000000  2410.000000  2410.000000
# mean      0.059773    42.713167  1431.113278   231.749793    13.592241
# std       0.013542    25.954066   752.459975   157.685604     2.352204
# min       0.001000     4.000000     1.000000     0.000000     8.400000
# 25%       0.050000    21.000000   808.250000    93.000000    12.000000
# 50%       0.056000    35.000000  1453.500000   205.000000    12.000000
# 75%       0.067000    64.000000  2075.750000   366.000000    16.000000
# max       0.128000   138.000000  2692.000000   557.000000    32.000000

# %% [markdown]
# ## Ejercicio 7
# ¿Cuántas birras hay de cada estilo en este dataset? [Investiga en la documentación de Series](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html) si puedes hacer un conteo de valores.

# %%
beers.head()
# Out:
#      abv  ibu    id                 name                           style  \
# 0  0.050  NaN  1436             Pub Beer             American Pale Lager
# 1  0.066  NaN  2265          Devil's Cup         American Pale Ale (APA)
# 2  0.071  NaN  2264  Rise of the Phoenix                    American IPA
# 3  0.090  NaN  2263             Sinister  American Double / Imperial IPA
# 4  0.075  NaN  2262        Sex and Candy                    American IPA
#
#    brewery_id  ounces
# 0         408    12.0
# 1         177    12.0
# 2         177    12.0
# 3         177    12.0
# 4         177    12.0

# %%
beers['style'].value_counts()
# Out:
# style
# American IPA                      424
# American Pale Ale (APA)           245
# American Amber / Red Ale          133
# American Blonde Ale               108
# American Double / Imperial IPA    105
#                                  ...
# American Malt Liquor                1
# Wheat Ale                           1
# Flanders Red Ale                    1
# Kristalweizen                       1
# Low Alcohol Beer                    1
# Name: count, Length: 99, dtype: int64

# %%
beers.groupby('style')['name'].count().sort_values(ascending= False)
# Out:
# style
# American IPA                      424
# American Pale Ale (APA)           245
# American Amber / Red Ale          133
# American Blonde Ale               108
# American Double / Imperial IPA    105
#                                  ...
# Smoked Beer                         1
# Flanders Red Ale                    1
# Kristalweizen                       1
# American Malt Liquor                1
# Flanders Oud Bruin                  1
# Name: name, Length: 99, dtype: int64

# %% [markdown]
# ## Ejercicio 8
# 1. Imprime por pantalla los registros desde el décimo hasta el vigésimo
# 2. De esos registros, imprime por pantalla desde la columna `name` a `ounces`, ambas incluidas
# 3. Quédate con las columnas `abv`, `ibu` y `ounces`, y además quédate sólo con los registros 10 al 20.
# 4. Convierte el resultado del apartado 3 en un array de `numpy`

# %%
beers.iloc[10:21, ::]
# Out:
#       abv   ibu    id                          name                    style  \
# 10  0.072   NaN  2099             Sophomoric Saison   Saison / Farmhouse Ale
# 11  0.073   NaN  2098         Regional Ring Of Fire   Saison / Farmhouse Ale
# 12  0.069   NaN  2097                    Garce Selé   Saison / Farmhouse Ale
# 13  0.085   NaN  1980               Troll Destroyer              Belgian IPA
# 14  0.061  60.0  1979                  Bitter Bitch  American Pale Ale (APA)
# 15  0.060   NaN  2318                   Ginja Ninja                    Cider
# 16  0.060   NaN  2170                 Cherried Away                    Cider
# 17  0.060   NaN  2169                  Rhubarbarian                    Cider
# 18  0.060   NaN  1502                   BrightCider                    Cider
# 19  0.082   NaN  1593   He Said Baltic-Style Porter            Baltic Porter
# 20  0.082   NaN  1592  He Said Belgian-Style Tripel                   Tripel
#
#     brewery_id  ounces
# ...

# %%
beers.iloc[10:21, ::].loc[::, 'name':'ounces']
# Out:
#                             name                    style  brewery_id  ounces
# 10             Sophomoric Saison   Saison / Farmhouse Ale         177    12.0
# 11         Regional Ring Of Fire   Saison / Farmhouse Ale         177    12.0
# 12                    Garce Selé   Saison / Farmhouse Ale         177    12.0
# 13               Troll Destroyer              Belgian IPA         177    12.0
# 14                  Bitter Bitch  American Pale Ale (APA)         177    12.0
# 15                   Ginja Ninja                    Cider         154    12.0
# 16                 Cherried Away                    Cider         154    12.0
# 17                  Rhubarbarian                    Cider         154    12.0
# 18                   BrightCider                    Cider         154    12.0
# 19   He Said Baltic-Style Porter            Baltic Porter         368    12.0
# 20  He Said Belgian-Style Tripel                   Tripel         368    12.0

# %%
beers.loc[10:20, 'name':'ounces']
# Out:
#                             name                    style  brewery_id  ounces
# 10             Sophomoric Saison   Saison / Farmhouse Ale         177    12.0
# 11         Regional Ring Of Fire   Saison / Farmhouse Ale         177    12.0
# 12                    Garce Selé   Saison / Farmhouse Ale         177    12.0
# 13               Troll Destroyer              Belgian IPA         177    12.0
# 14                  Bitter Bitch  American Pale Ale (APA)         177    12.0
# 15                   Ginja Ninja                    Cider         154    12.0
# 16                 Cherried Away                    Cider         154    12.0
# 17                  Rhubarbarian                    Cider         154    12.0
# 18                   BrightCider                    Cider         154    12.0
# 19   He Said Baltic-Style Porter            Baltic Porter         368    12.0
# 20  He Said Belgian-Style Tripel                   Tripel         368    12.0

# %%
beers.loc[10:20, ['abv', 'ibu', 'ounces']]
# Out:
#       abv   ibu  ounces
# 10  0.072   NaN    12.0
# 11  0.073   NaN    12.0
# 12  0.069   NaN    12.0
# 13  0.085   NaN    12.0
# 14  0.061  60.0    12.0
# 15  0.060   NaN    12.0
# 16  0.060   NaN    12.0
# 17  0.060   NaN    12.0
# 18  0.060   NaN    12.0
# 19  0.082   NaN    12.0
# 20  0.082   NaN    12.0

# %%
beers.loc[10:20, ['abv', 'ibu', 'ounces']].values
# Out:
# array([[ 0.072,    nan, 12.   ],
#        [ 0.073,    nan, 12.   ],
#        [ 0.069,    nan, 12.   ],
#        [ 0.085,    nan, 12.   ],
#        [ 0.061, 60.   , 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.082,    nan, 12.   ],
#        [ 0.082,    nan, 12.   ]])

# %% [markdown]
# ## Ejercicio 9
# ¿Cuántas onzas pesan todas las birras del dataset?

# %%
beers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   abv         2348 non-null   float64
#  1   ibu         1405 non-null   float64
#  2   id          2410 non-null   int64
#  3   name        2410 non-null   object
#  4   style       2405 non-null   object
#  5   brewery_id  2410 non-null   int64
#  6   ounces      2410 non-null   float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 131.9+ KB

# %%
beers['ounces'].sum()
# Out:
# 32757.3

# %% [markdown]
# ## Ejercicio 10
# El amargor de las cervezas se mide por su nivel de IBUs.
# 1. ¿Cuál es el amargor medio de las cervezas?
# 2. ¿El máximo? ¿Y el mínimo?
# 3. ¿Qué cerveza es la que tiene el amargor máximo? ¿Cuál es la de amargor mínimo?

# %%
beers['ibu'].mean()
# Out:
# 42.71316725978647

# %%
beers['ibu'].agg(['max', 'min'])
# Out:
# max    138.0
# min      4.0
# Name: ibu, dtype: float64

# %%
beers[['name', 'ibu']][(beers['ibu'] == beers['ibu'].max()) | (beers['ibu'] == beers['ibu'].min())]
# Out:
#                                      name    ibu
# 106                       Summer Solstice    4.0
# 112  Summer Solstice Cerveza Crema (2009)    4.0
# 117                Summer Solstice (2011)    4.0
# 147             Bitter Bitch Imperial IPA  138.0

# %% [markdown]
# ## Ejercicio 11
# No queda muy claro cuánto de dispar, de dispersa, es la medida de IBU. Mediante estadística descriptiva (una o dos métricas, sin gráficas), razona la dispersión de la variable IBU.

# %%
beers['ibu'].describe()
# Out:
# count    1405.000000
# mean       42.713167
# std        25.954066
# min         4.000000
# 25%        21.000000
# 50%        35.000000
# 75%        64.000000
# max       138.000000
# Name: ibu, dtype: float64

# %%
beers['ibu'].var()
# Out:
# 673.6135373259929

# %%
import seaborn as sns

# %%
sns.displot(beers['ibu'], kind= 'kde');
# Out:
# c:\Users\misla\.pyenv\pyenv-win\versions\3.9.7\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(beers['ibu'], orient= 'h');

# %%
beers['name'][beers['ibu'] >= 120]
# Out:
# 147           Bitter Bitch Imperial IPA
# 525                       Dead-Eye DIPA
# 594     Bay of Bengal Double IPA (2014)
# 2081                       Abrasive Ale
# 2144                       Heady Topper
# 2145                       Heady Topper
# 2390                 Troopers Alley IPA
# Name: name, dtype: object

# %% [markdown]
# ## Ejercicio 12
# ¿Existe alguna relación lineal entre las variables numéricas del dataset? Intenta pintar este razonmiento mediante un gráfico

# %%
beers.corr(numeric_only= True)
# Out:
#                  abv       ibu        id  brewery_id    ounces
# abv         1.000000  0.670621  0.042811   -0.098632  0.172529
# ibu         0.670621  1.000000  0.000485   -0.004875  0.054691
# id          0.042811  0.000485  1.000000   -0.504030  0.100843
# brewery_id -0.098632 -0.004875 -0.504030    1.000000 -0.133762
# ounces      0.172529  0.054691  0.100843   -0.133762  1.000000

# %%
sns.heatmap(beers.corr(numeric_only= True), annot= True);

# %%
sns.pairplot(beers);
# Out:
# c:\Users\misla\.pyenv\pyenv-win\versions\3.9.7\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Ejercicio 13
# Representa el nivel de alcohol (columna `abv`) en un histograma. ¿Se trata de una distribución simétrica o asimétrica?

# %%
sns.histplot(beers['abv'], kde= True);

# %%
beers['abv'].skew()
# Out:
# 0.9584771340361382

# %% [markdown]
# ## Ejercicio 14
# Representa mediante un *boxplot* de `seaborn` la variable `abv`

# %%
sns.boxplot(beers['abv'], orient= 'h')
# Out:
# <Axes: >

# %%
beers[(beers['abv'] > 0.083) & (beers['abv'] < 0.10)]['style'].unique()
# Out:
# array(['American Double / Imperial IPA', 'Belgian IPA',
#        'American Barleywine', 'English Strong Ale',
#        'Belgian Strong Dark Ale', 'American Stout',
#        'American Double / Imperial Stout', 'Tripel', 'Rye Beer',
#        'Saison / Farmhouse Ale', 'Quadrupel (Quad)', 'Belgian Dark Ale',
#        'American Wild Ale', 'Russian Imperial Stout', 'Schwarzbier',
#        'Pumpkin Ale', 'American Black Ale', 'Scotch Ale / Wee Heavy',
#        'American IPA', 'Old Ale', 'Winter Warmer', 'American Brown Ale',
#        'Witbier', 'American Malt Liquor', 'German Pilsener',
#        'Belgian Pale Ale', 'Scottish Ale', 'Belgian Strong Pale Ale',
#        'Baltic Porter', 'American Strong Ale', 'English Barleywine',
#        'Dubbel', 'Herbed / Spiced Beer'], dtype=object)

# %% [markdown]
# ## Ejercicio 15
# 1. ¿Qué estilos son los que tienen en media más alcohol?
# 2. ¿Y los estilos que son en media más amargos?

# %%
beers[['style', 'abv']].groupby('style').mean().sort_values(by= 'abv', ascending= False).head()
# Out:
#                              abv
# style
# English Barleywine      0.107667
# Quadrupel (Quad)        0.104000
# American Barleywine     0.099000
# American Malt Liquor    0.099000
# Russian Imperial Stout  0.097636

# %%
beers[['style', 'ibu']].groupby('style').mean().sort_values(by= 'ibu', ascending= False).head()
# Out:
#                                       ibu
# style
# American Barleywine                 96.00
# American Double / Imperial IPA      93.32
# Russian Imperial Stout              86.50
# American Double / Imperial Pilsner  85.00
# Belgian Strong Dark Ale             72.00

# %% [markdown]
# ## Ejercicio 16
# Carga el datasets de cervecerias `datasets_breweries.csv`

# %%
breweries = pd.read_csv('data/datasets_breweries.csv')

# %% [markdown]
# ## Ejercicio 17
# 1. Renombra la columna `Unnamed: 0` como `brewery_id`
# 2. Renombra tb la columna `name` por `brewery_name`. ¿Puedes hacer ambos apartados en una sola sentencia?

# %%
breweries.rename(columns={'Unnamed: 0': 'brewery_id', 'name': 'brewery_name'}, inplace= True)

# %%
breweries.head()
# Out:
#    brewery_id               brewery_name           city state
# 0           0         NorthGate Brewing     Minneapolis    MN
# 1           1  Against the Grain Brewery     Louisville    KY
# 2           2   Jack's Abby Craft Lagers     Framingham    MA
# 3           3  Mike Hess Brewing Company      San Diego    CA
# 4           4    Fort Point Beer Company  San Francisco    CA

# %% [markdown]
# ## Ejercicio 18
# Junta los dos datasets que tienes

# %%
beers.head()
# Out:
#      abv  ibu    id                 name                           style  \
# 0  0.050  NaN  1436             Pub Beer             American Pale Lager
# 1  0.066  NaN  2265          Devil's Cup         American Pale Ale (APA)
# 2  0.071  NaN  2264  Rise of the Phoenix                    American IPA
# 3  0.090  NaN  2263             Sinister  American Double / Imperial IPA
# 4  0.075  NaN  2262        Sex and Candy                    American IPA
#
#    brewery_id  ounces
# 0         408    12.0
# 1         177    12.0
# 2         177    12.0
# 3         177    12.0
# 4         177    12.0

# %%
breweries.head()
# Out:
#    brewery_id               brewery_name           city state
# 0           0         NorthGate Brewing     Minneapolis    MN
# 1           1  Against the Grain Brewery     Louisville    KY
# 2           2   Jack's Abby Craft Lagers     Framingham    MA
# 3           3  Mike Hess Brewing Company      San Diego    CA
# 4           4    Fort Point Beer Company  San Francisco    CA

# %%
merged_breweries = pd.merge(beers, breweries, on= 'brewery_id', how= 'inner')

# %%
merged_breweries
# Out:
#         abv   ibu    id                  name                           style  \
# 0     0.050   NaN  1436              Pub Beer             American Pale Lager
# 1     0.066   NaN  2265           Devil's Cup         American Pale Ale (APA)
# 2     0.071   NaN  2264   Rise of the Phoenix                    American IPA
# 3     0.090   NaN  2263              Sinister  American Double / Imperial IPA
# 4     0.075   NaN  2262         Sex and Candy                    American IPA
# ...     ...   ...   ...                   ...                             ...
# 2405  0.067  45.0   928             Belgorado                     Belgian IPA
# 2406  0.052   NaN   807         Rail Yard Ale        American Amber / Red Ale
# 2407  0.055   NaN   620       B3K Black Lager                     Schwarzbier
# 2408  0.055  40.0   145   Silverback Pale Ale         American Pale Ale (APA)
# 2409  0.052   NaN    84  Rail Yard Ale (2009)        American Amber / Red Ale
#
# ...

# %% [markdown]
# ## Ejercicio 19
# 1. ¿Cuántos estados diferentes hay?
# 2. ¿Y ciudades diferentes?
# 3. ¿Cuántas cervecerías hay?

# %%
merged_breweries['state'].nunique()
# Out:
# 51

# %%
merged_breweries['city'].nunique()
# Out:
# 384

# %%
merged_breweries['brewery_id'].nunique()
# Out:
# 558

# %% [markdown]
# ## Ejercicio 20
# Agrupa por estado y ciudad, la media, mediana y máximo nivel de alcohol

# %%
merged_breweries[['state', 'city', 'abv']].groupby(['state', 'city']).agg(['mean', 'median', 'max'])
# Out:
#                        abv
#                       mean  median    max
# state city
#  AK   Anchorage   0.054200  0.0520  0.063
#       Juneau      0.053000  0.0530  0.053
#       Soldotna    0.058500  0.0580  0.068
#       Talkeetna   0.059500  0.0585  0.065
#  AL   Birmingham  0.065400  0.0600  0.093
# ...                    ...     ...    ...
#  WI   Wilson      0.055000  0.0550  0.055
#  WV   Lewisburg   0.062000  0.0620  0.067
#  WY   Jackson     0.054857  0.0520  0.068
#       Pinedale    0.061000  0.0610  0.072
#       Sheridan    0.052833  0.0480  0.070
#
# [401 rows x 3 columns]

# %% [markdown]
# ## Ejercicio 21
# ¿Cuáles son las cervezas más amargas que se consumen en Indiana, estado = `IN`?

# %%
merged_breweries['state'][merged_breweries['state'].str.contains('IN')].str[1::]
# Out:
# 1       IN
# 2       IN
# 3       IN
# 4       IN
# 5       IN
#         ..
# 2195    IN
# 2275    IN
# 2276    IN
# 2277    IN
# 2329    IN
# Name: state, Length: 139, dtype: object

# %%
merged_breweries['state'][merged_breweries['state'].str.contains('IN')] = merged_breweries['state'][merged_breweries['state'].str.contains('IN')].str[1::]
# Out:
# C:\Users\misla\AppData\Local\Temp\ipykernel_9228\833913195.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_breweries['state'][merged_breweries['state'].str.contains('IN')] = merged_breweries['state'][merged_breweries['state'].str.contains('IN')].str[1::]

# %%
merged_breweries[['name', 'ibu', 'state']]\
    [merged_breweries['state'] == 'IN'].sort_values(by= 'ibu', ascending= False).head()
# Out:
#                        name    ibu state
# 479        Hopkick Dropkick  115.0    IN
# 2191  Overlord Imperial IPA  115.0    IN
# 811          Half Cycle IPA  104.0    IN
# 2062                   Isis   91.0    IN
# 2189                   Csar   90.0    IN

# %% [markdown]
# ## Ejercicio 22
# Obtén una tabla con los principales estadísticos del campo `ibu`,  a nivel ciudad

# %%
merged_breweries[['ibu', 'city']].groupby('city').describe()
# Out:
#                  ibu                                                       \
#                count        mean        std    min     25%    50%     75%
# city
# Abingdon         1.0  135.000000        NaN  135.0  135.00  135.0  135.00
# Abita Springs    3.0   27.333333  21.455380   13.0   15.00   17.0   34.50
# Ada              0.0         NaN        NaN    NaN     NaN    NaN     NaN
# Afton            4.0   43.000000  19.899749   22.0   28.00   45.0   60.00
# Airway Heights   0.0         NaN        NaN    NaN     NaN    NaN     NaN
# ...              ...         ...        ...    ...     ...    ...     ...
# Woodinville      4.0   46.750000  18.643587   27.0   39.75   44.0   51.00
# Worcester        1.0   69.000000        NaN   69.0   69.00   69.0   69.00
# Yakima           2.0   54.000000  22.627417   38.0   46.00   54.0   62.00
# Yardley          0.0         NaN        NaN    NaN     NaN    NaN     NaN
# York             4.0   44.250000  22.779742   20.0   35.00   41.0   50.25
#
# ...

# %% [markdown]
# ## Ejercicio 23
# Consigue en un DataFrame todas las cervezas en cuyas cervecerías al menos haya una cerveza con un `abv` mínimo 0.07.

# %%
# def filtro(df):
#     return df['abv'].min() >= 0.07

# %%
# def minimoABV(df3, variable1, variable2):
#     for (df3, group) in df3.groupby(f"{variable1}"):
#         if group["abv"].count() >= 0.07:
#             print(f"{group[variable2]}")

# minimoABV(df3, "brewery_name", "name")

# %%
merged_breweries[['name', 'brewery_id', 'abv']].groupby('brewery_id').filter(filtro)
# Out:
#                                          name  brewery_id    abv
# 137       Green Bullet Organic India Pale Ale         429  0.070
# 191                                  Thai.p.a          20  0.070
# 212                       Hoptopus Double IPA         306  0.088
# 275                            Saucy Intruder          18  0.072
# 286                             Flying Sailor          95  0.073
# 309                   Quarter Mile Double IPA         304  0.080
# 354                               Noche Dulce         231  0.071
# 594           Bay of Bengal Double IPA (2014)          99  0.089
# 690                              Lift Off IPA         358  0.072
# 752               Nut Sack Imperial Brown Ale         465  0.070
# 884                           Salamander Slam         180  0.070
# 905                            Vanilla Porter          39  0.070
# 1142                           Sucha Much IPA         208  0.071
# ...

# %%
breweries_007 = beers['brewery_id'][beers['abv'] >= 0.07].unique()

# %%
beers[['name']][beers['brewery_id'].isin(breweries_007)]
# Out:
#                       name
# 1              Devil's Cup
# 2      Rise of the Phoenix
# 3                 Sinister
# 4            Sex and Candy
# 5             Black Exodus
# ...                    ...
# 2405             Belgorado
# 2406         Rail Yard Ale
# 2407       B3K Black Lager
# 2408   Silverback Pale Ale
# 2409  Rail Yard Ale (2009)
#
# [1483 rows x 1 columns]

# %%
beers
# Out:
#         abv   ibu    id                  name                           style  \
# 0     0.050   NaN  1436              Pub Beer             American Pale Lager
# 1     0.066   NaN  2265           Devil's Cup         American Pale Ale (APA)
# 2     0.071   NaN  2264   Rise of the Phoenix                    American IPA
# 3     0.090   NaN  2263              Sinister  American Double / Imperial IPA
# 4     0.075   NaN  2262         Sex and Candy                    American IPA
# ...     ...   ...   ...                   ...                             ...
# 2405  0.067  45.0   928             Belgorado                     Belgian IPA
# 2406  0.052   NaN   807         Rail Yard Ale        American Amber / Red Ale
# 2407  0.055   NaN   620       B3K Black Lager                     Schwarzbier
# 2408  0.055  40.0   145   Silverback Pale Ale         American Pale Ale (APA)
# 2409  0.052   NaN    84  Rail Yard Ale (2009)        American Amber / Red Ale
#
#       brewery_id  ounces
# ...

# %% [markdown]
# ## Ejercicio 24
# Teniendo en cuenta la media de amargor de todas las cervezas, obtén una tabla con las cervezas cuyos estados tengan una media de amargor en cerveza por encima de la media

# %%
merged_breweries['ibu'].mean()
# Out:
# 42.71316725978647

# %%
states_ibu_mean = merged_breweries[['state', 'ibu']].groupby('state').mean()

# %%
states_ibu_to_filter = states_ibu_mean[states_ibu_mean['ibu'] > merged_breweries['ibu'].mean()].index

# %%
states_ibu_to_filter
# Out:
# Index([' AL', ' CA', ' CO', ' DC', ' DE', ' FL', ' GA', ' ID', ' ME', ' MN',
#        ' MS', ' NC', ' NH', ' NJ', ' NM', ' NV', ' NY', ' OH', ' OR', ' UT',
#        ' VA', ' WA', ' WV', 'IN'],
#       dtype='object', name='state')

# %%
merged_breweries['name'][merged_breweries['state'].isin(states_ibu_to_filter)]
# Out:
# 0                   Pub Beer
# 1                Devil's Cup
# 2        Rise of the Phoenix
# 3                   Sinister
# 4              Sex and Candy
#                 ...
# 2405               Belgorado
# 2406           Rail Yard Ale
# 2407         B3K Black Lager
# 2408     Silverback Pale Ale
# 2409    Rail Yard Ale (2009)
# Name: name, Length: 1288, dtype: object
