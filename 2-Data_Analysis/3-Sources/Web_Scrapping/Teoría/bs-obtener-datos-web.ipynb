# %% [markdown]
# ### Web Scrapping con Beautiful Soup (lvl. 2)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Pasos iniciales
sitio = "http://programminghistorian.org/es/lecciones/"
respuesta = requests.get(sitio)
contenido = respuesta.text

# %%
soup = BeautifulSoup(contenido, "html.parser")

# %%
print(contenido)
# Out:
# <!DOCTYPE html>
# <html lang="es">
#
#   <head>
#   <meta charset="utf-8">
#   <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#
#
#
#
#
#   <link rel="shortcut icon" href="/images/favicons/es_favicon.ico" type="image/x-icon">
#
#   <!-- Mobile viewport optimized: h5bp.com/viewport -->
#   <meta name="viewport" content="width=device-width">
#
#   <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.0.12/css/all.css" integrity="sha384-G0fIWCsCzJIMAVNQPfjH08cyYaUtMwjJwqiRKxxE/rx96Uroj1BtIQ6MLJuheaO9" crossorigin="anonymous">
#
#   <link href='/feed.xml' rel='alternate' type='application/atom+xml'>
#
#   <title>Índice de lecciones | Programming Historian</title>
#
#   <link href="https://fonts.googleapis.com/css?family=Crete+Round|Open+Sans|Quattrocento|Roboto|Roboto+Condensed" rel="stylesheet">
#
#   <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0-alpha.6/css/bootstrap.min.css" integrity="sha384-rwoIResjU2yc3z8GV/NPeZWAv56rSmLldC3R/AZzGRnGxQQKnKkoFVhFQhNUwEyJ" crossorigin="anonymous" media="all">
#   <link rel="stylesheet" href="/css/github.css">
#   <link rel="stylesheet" href="/css/style.css">
#
#   <script
#     src="https://code.jquery.com/jquery-3.2.1.min.js"
#     integrity="sha256-hwg4gsxgFZhOsEEamdOYGBf13FyQuiTwlAQgxVSNgt4="
#     crossorigin="anonymous"></script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/tether/1.4.0/js/tether.min.js" integrity="sha384-DztdAPBWPRXSA/3eYEEUWrWCy7G5KFbe8fFjk5JAIxUYHKkDx6Qin1DkWx51bBrb" crossorigin="anonymous"></script>
#   <script src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0-alpha.6/js/bootstrap.min.js" integrity="sha384-vBWWzlZJ8ea9aCX4pEW3rVHjgjt7zpkNpZk+02D9phzyeVkE+jo0ieGizqPLForn" crossorigin="anonymous"></script>
#
#   <script type="text/javascript" src="/js/ext_links.js"></script>
#   <script type="text/javascript" src="/js/header_links.js"></script>
#
#
#
#
#   <script src="/js/bootstrap-4-navbar.js"></script>
#
# </head>
#
#
#   <body>
#
#
#
# <div class="alert alert-success sitewide-alert text-center">
#   <h2><a href="https://www.patreon.com/theprogramminghistorian" class="alert-link">¡Haz una donación a <i>Programming Historian</i>!</a></h2>
#
# </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <nav class="hide-screen navbar navbar-toggleable-md navbar-dark bg-dark"
#   style="background-color: #535D7F" role="navigation">
#   <!--<div class="container">-->
#   <button class="navbar-toggler navbar-toggler-right" type="button" data-toggle="collapse"
#     data-target="#navbarNavDropdown" aria-controls="navbarNavDropdown" aria-expanded="false"
#     aria-label="Toggle navigation">
#     <span class="navbar-toggler-icon"></span>
#   </button>
#   <a class="navbar-brand" href="/es">Programming
#     Historian</a>
#   <div class="collapse navbar-collapse" id="navbarNavDropdown">
#     <ul class="nav navbar-nav ml-auto w-100 justify-content-end" role="menubar">
#       <li class="nav-item dropdown mobile-drop" role="menu">
#         <a class="nav-link dropdown-toggle" id="navbarDropdownMenuLink" data-toggle="dropdown" aria-haspopup="true"
#           aria-expanded="false" role="button">
#           Acerca
#         </a>
#         <div class="dropdown-menu" aria-labelledby="navbarDropdownMenuLink">
#           <a class="dropdown-item" href="/es/acerca-de"
#             role="menuitem">Acerca</a>
#           <a class="dropdown-item" href="/es/equipo-de-proyecto"
#             role="menuitem">Equipo</a>
#           <a class="dropdown-item" href="/es/investigacion"
#             role="menuitem">Investigación</a>
#           <a class="dropdown-item" href="/es/vacantes"
#             role="menuitem">Vacantes</a>
#           <a class="dropdown-item" href="/es/politica-de-privacidad"
#             role="menuitem">Política de privacidad</a>
#         </div>
#       </li>
#
#       <li class="nav-item dropdown mobile-drop" role="menu">
#         <a class="nav-link dropdown-toggle" id="navbarDropdownMenuLink2" data-toggle="dropdown" aria-haspopup="true"
#           aria-expanded="false" role="button">
#           Contribuciones
#         </a>
#         <div class="dropdown-menu" aria-labelledby="navbarDropdownMenuLink2">
#           <a class="dropdown-item"
#             href="/es/contribuciones"
#             role="menuitem">Contribuciones</a>
#           <a class="dropdown-item"
#             href="/es/retroalimentacion"
#             role="menuitem">Reporta un error</a>
#           <a class="dropdown-item" href="/es/guia-para-revisores"
#             role="menuitem">Guía para revisores</a>
#           <a class="dropdown-item" href="/es/guia-para-autores"
#             role="menuitem">Guía para autores</a>
#           <a class="dropdown-item"
#             href="/es/guia-para-traductores"
#             role="menuitem">Guía para traductores</a>
#           <a class="dropdown-item" href="/es/guia-editor"
#             role="menuitem">Guía para editores</a>
#           <a class="dropdown-item"
#             href="https://github.com/programminghistorian/jekyll/wiki/Making-Technical-Contributions"
#             role="menuitem">Contribuciones técnicas</a>
#         </div>
#       </li>
#
#       <li class="nav-item" role="menuitem">
#         <a class="nav-link" href="/es/lecciones"
#           role="link">Lecciones</a>
#       </li>
#
#         <li class="nav-item" role="menuitem">
#       <a class="nav-link" href="/es/eventos"
#          role="link">Eventos</a>
#       </li>
#
#       <li class="nav-item dropdown mobile-drop" role="menu">
#         <a class="nav-link dropdown-toggle" id="navbarDropdownMenuLink3" data-toggle="dropdown" aria-haspopup="true"
#           aria-expanded="false" role="button">
#           Apóyanos
#         </a>
#         <div class="dropdown-menu" aria-labelledby="navbarDropdownMenuLink3">
#         <a class="dropdown-item" href="/es/pia"
#           role="menuitem">Programa de Instituciones Asociadas</a>
#         <a class="dropdown-item" href="/es/donaciones"
#           role="menuitem">Apóyanos - Donaciones</a>
#         <a class="dropdown-item" href="/es/colaboradores"
#           role="menuitem">Colaboradores</a>
#       </li>
#
#       <li class="nav-item" role="menuitem">
#         <a class="nav-link" href="/blog"
#           role="link">Blog</a>
#       </li>
#
#
#
#
#       <li class="nav-item" role="menu">
#         <div class="btn-group" role="menuitem" aria-label="Language selector">
#
#
#
#
#
#
#
#           <a class="btn btn-secondary nav-link" role="button"
#             href="/en/lessons/">en</a>
#
#
#
#
#
#           <a class="btn btn-secondary nav-link active disabled" role="button"
#             aria-pressed="true">es</a>
#
#
#
#
#
#
#
#
#           <a class="btn btn-secondary nav-link" role="button"
#             href="/fr/lecons/">fr</a>
#
#
#
#
#
#
#
#
#
#           <a class="btn btn-secondary nav-link" role="button"
#             href="/pt/licoes/">pt</a>
#
#
#
#         </div>
#       </li>
#       <li class="nav-item" id="low-contrast-button" role="menu">
#         <div class="theme-switch-wrapper">
#           <label class="theme-switch" role="menuitem">
#             <input type="checkbox" role="menuitemcheckbox">
#             <span class="slider round">
#               <span class="visually-hidden">night mode toggle</span>
#             </span>
#           </label>
#         </div>
#       </li>
#     </ul>
#   </div>
#   <!--</div>-->
# </nav>
#
# <nav class="hide-print print-header navbar-brand">Programming Historian </nav>
#
# <script>
#   const toggleSwitch = document.querySelector('.theme-switch input[type="checkbox"]');
#   function setTheme(currentTheme) {
#     document.documentElement.setAttribute('data-theme', currentTheme);
#     sessionStorage.setItem('theme', currentTheme);
#   }
#
#   let theme = sessionStorage.getItem('theme') === null ? 'day' : sessionStorage.getItem('theme');
#
#   toggleSwitch.checked = theme === 'night' ? true : false;
#
#   setTheme(theme);
#
#   toggleSwitch.addEventListener('change', function(e){
#     setTheme(e.target.checked ? 'night': 'day')
#   }, false);
#
# </script>
#
#
#     <div class="container">
#       <article>
#         <h1 id="índice">Índice</h1>
#
# <p>Nuestras lecciones se organizan en fases del proceso de investigación y por temas generales. Utiliza los botones para filtrar las lecciones por categoría. Si no encuentras una habilidad, técnica o herramienta, por favor, ponte en <a href="/es/retroalimentacion">contacto</a> con nosotros.</p>
#
# <!-- loading graph if search in URI -->
# <div id="pre-loader">
#   <svg width="200" height="200" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 100 100" preserveAspectRatio="xMidYMid" class="lds-ripple" style="background:0 0">
#     <circle cx="50" cy="50" r="4.719" fill="none" stroke="#1d3f72" stroke-width="2">
#       <animate attributeName="r" calcMode="spline" values="0;40" keyTimes="0;1" dur="3" keySplines="0 0.2 0.8 1" begin="-1.5s" repeatCount="indefinite" />
#       <animate attributeName="opacity" calcMode="spline" values="1;0" keyTimes="0;1" dur="3" keySplines="0.2 0 0.8 1" begin="-1.5s" repeatCount="indefinite" />
#     </circle>
#     <circle cx="50" cy="50" r="27.591" fill="none" stroke="#5699d2" stroke-width="2">
#       <animate attributeName="r" calcMode="spline" values="0;40" keyTimes="0;1" dur="3" keySplines="0 0.2 0.8 1" begin="0s" repeatCount="indefinite" />
#       <animate attributeName="opacity" calcMode="spline" values="1;0" keyTimes="0;1" dur="3" keySplines="0.2 0 0.8 1" begin="0s" repeatCount="indefinite" />
#     </circle>
#   </svg>
# </div>
# <ul class="filter activities">
#
#
#   <li id="filter-acquiring" class="filter">obtener (7)
#   </li>
#
#
#   <li id="filter-transforming" class="filter">transformar (27)
#   </li>
#
#
#   <li id="filter-analyzing" class="filter">analizar (12)
#   </li>
#
#
#   <li id="filter-presenting" class="filter">presentar (12)
#   </li>
#
#
#   <li id="filter-sustaining" class="filter">preservar (2)
#   </li>
#
# </ul>
#
# <ul class="filter topics">
#
#
#
#
#
#
#
#
#   <li id="filter-python" class="filter">Python (20)</li>
#
#
#
#
#
#   <li id="filter-data-management" class="filter">Gestión de datos (5)</li>
#
#
#
#
#
#   <li id="filter-data-manipulation" class="filter">Procesamiento de datos (13)</li>
#
#
#
#
#
#   <li id="filter-distant-reading" class="filter">Lectura distante (9)</li>
#
#
#
#
#
#   <li id="filter-get-ready" class="filter">Instalar (8)</li>
#
#
#
#
#
#   <li id="filter-lod" class="filter">Datos abiertos enlazados (2)</li>
#
#
#
#
#
#   <li id="filter-mapping" class="filter">Mapeado (4)</li>
#
#
#
#
#
#   <li id="filter-network-analysis" class="filter">Análisis de redes (3)</li>
#
#
#
#
#
#   <li id="filter-web-scraping" class="filter">Web Scraping (4)</li>
#
#
#
#
#
#   <li id="filter-website" class="filter">Publicación digital (12)</li>
#
#
#
#
#
#   <li id="filter-r" class="filter">R (8)</li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#   <li id="filter-creative-coding" class="filter">programación creativa (1)</li>
#
#
# </ul>
#
# <div id="filter-none">restaurar para ver todas las lecciones (60)</div>
#
# <!--
# this div ('lesson-list', referenced in lessonfilter.js) needs to contain the sort button/elements AND the actual list for the sort buttons to work
# -->
# <div id="search-div" style="text-align: center; margin-bottom: 1rem; display: none;">
#   <input id="loading-search" class="search-input" type="text" placeholder="CARGANDO LA BÚSQUEDA..." style="background-color: #efefef" disabled="" />
#   <input id="search" class="search-input" type="text" style="display: none;" placeholder="ESCRIBE LOS TÉRMINOS DE BÚSQUEDA..." />
#   <button id="search-button" disabled="">BUSCAR LECCIONES</button>
#   <i id="search-info-button" class="fas fa-question-circle"></i>
#   <div id="search-info">
#     <p>Para buscar términos relevantes, escríbelos en la barra de búsqueda y aprieta la tecla “enter” o haz clic en el botón “buscar lecciones”. Las búsquedas no distinguen mayúsculas y minúsculas. Si se ingresan múltiples términos, los resultados incluirán tanto lecciones que los contengan todos, como lecciones que contengan <em>solo alguno</em>. Los resultados que incluyan más de un término aparecerán primero en la lista.</p>
#
# <p>Para obtener solo resultados con múltiples términos, agrega el símbolo <code class="language-plaintext highlighter-rouge">+</code> antes de cada uno. Por ejemplo, <code class="language-plaintext highlighter-rouge">+Twitter +Red</code> devolverá lecciones que contienen <em>tanto</em> “twitter” como “red”. Para obtener solo resultados que <em>no</em> contengan cierto término, utiliza el símbolo <code class="language-plaintext highlighter-rouge">-</code>. Por ejemplo, <code class="language-plaintext highlighter-rouge">-Twitter +Red</code> devolverá lecciones que contienen “red” pero no “twitter”. Para información más detallada, puedes revisar la guía sobre búsquedas (en inglés): <a href="https://lunrjs.com/guides/searching.html">https://lunrjs.com/guides/searching.html</a></p>
#
#   </div>
# </div>
# <div id="enable-search-div" style="text-align: center; margin-bottom: 1rem;">
#   <button id="enable-search-button" style="width: 100%;">INICIAR BÚSQUEDA</button>
# </div>
#
# <div id="lesson-list">
#
#   <!--
# List.js uses button classes of asc and desc to control sorting functionality. It also toggles those classes off and on with click events.
# To not interfere with that, we use my-asc and my-desc to control the arrows, since our desired behavior is different from what list.js does.
# More concretely: to sort asc, the button class needs to contain asc, but we use the arrow ON THE BUTTON to indicate what WILL happen,
# not what IS HAPPENING (the filter header displays the current sort state). In order to have a down arrow, we use a my-desc class.
# Yes, this is confusing. But using two differnt classes allows us to separate functionality and presentation.
# -->
#   <ul class="sort-by">
#     <li id="sort-by-date" class="sort" data-sort="date">ordenar por fecha de publicación</li>
#     <li id="sort-by-difficulty" class="sort" data-sort="difficulty">ordena por dificultad
#     </li>
#   </ul>
#
#   <input id="date-sort-text" type="hidden" label="fecha" />
#   <input id="difficulty-sort-text" type="hidden" label="dificultad" />
#
#
#   <h2 class="results-title">Filtradas por: <span id="results-value">Todas las lecciones </span> <span id="current-sort" class="sort-desc">fecha</span></h2>
#
#   <ul class="list">
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/administracion-de-datos-en-r"><img class="rounded" src="/gallery/data_wrangling_and_management_in_R.png" alt="Anuncio de pastilla de jabón" /><span class="visually-hidden">Administración de datos en R</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# Nabeel Siddiqui </h3>
#   <a href="/es/lecciones/administracion-de-datos-en-r"><h2 class="title">Administración de datos en R</h2></a>
#
#   <p class="abstract">
#     Este tutorial explora la manera en que los académicos pueden administrar datos de forma ordenada, entender paquetes de R para manipular los datos y llevar a cabo un análisis básico de datos.
#
#   </p>
#
#
#   <span class="activity">transforming</span>
#   <span class="topics">data-manipulation data-management distant-reading r</span>
#   <span class="date">2018-10-10</span>
#   <span class="difficulty">2</span>
#   <span id="/es/lecciones/administracion-de-datos-en-r-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/administracion-de-datos-en-r-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/analisis-de-corpus-con-antconc"><img class="rounded" src="/gallery/corpus-analysis-with-antconc.png" alt="Grabado de una estantería con libros" /><span class="visually-hidden">Análisis de corpus con AntConc</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# Heather Froehlich </h3>
#   <a href="/es/lecciones/analisis-de-corpus-con-antconc"><h2 class="title">Análisis de corpus con AntConc</h2></a>
#
#   <p class="abstract">
#     El análisis de corpus permite hacer comparaciones a gran escala entre objetos presentes en los textos; es decir, lo que se conoce como lectura distante.
#
#   </p>
#
#
#   <span class="activity">analyzing</span>
#   <span class="topics">distant-reading</span>
#   <span class="date">2018-05-04</span>
#   <span class="difficulty">1</span>
#   <span id="/es/lecciones/analisis-de-corpus-con-antconc-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/analisis-de-corpus-con-antconc-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/analisis-de-correspondencia-en-r"><img class="rounded" src="/gallery/correspondence-analysis-in-R.png" alt="Diagrama de un cubo con aristas etiquetadas" /><span class="visually-hidden">Análisis de correspondencia para la investigación histórica usando R
# </span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# Ryan Deschamps </h3>
#   <a href="/es/lecciones/analisis-de-correspondencia-en-r"><h2 class="title">Análisis de correspondencia para la investigación histórica usando R
# </h2></a>
#
#   <p class="abstract">
#     Este tutorial explica cómo implementar e interpretar un análisis de correspondencia, el que puede ser utilizado para identificar relaciones entre datos categóricos.
#
#   </p>
#
#
#   <span class="activity">analyzing</span>
#   <span class="topics">data-manipulation network-analysis r</span>
#   <span class="date">2022-04-11</span>
#   <span class="difficulty">3</span>
#   <span id="/es/lecciones/analisis-de-correspondencia-en-r-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/analisis-de-correspondencia-en-r-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/analisis-de-sentimientos-r"><img class="rounded" src="/gallery/analisis-de-sentimientos-r.png" alt="Grabado de tres rostros expresando distintas emociones" /><span class="visually-hidden">Análisis de sentimientos en R con 'syuzhet'</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# Jennifer Isasi </h3>
#   <a href="/es/lecciones/analisis-de-sentimientos-r"><h2 class="title">Análisis de sentimientos en R con 'syuzhet'</h2></a>
#
#   <p class="abstract">
#     Esta lección te enseña una forma de obtener y analizar datos sobre las emociones y los sentimientos de una narración
#
#   </p>
#
#
#   <span class="activity">analyzing</span>
#   <span class="topics">distant-reading r</span>
#   <span class="date">2021-03-23</span>
#   <span class="difficulty">2</span>
#   <span id="/es/lecciones/analisis-de-sentimientos-r-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/analisis-de-sentimientos-r-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/analisis-temporal-red"><img class="rounded" src="/gallery/temporal-network-analysis-with-r.png" alt="Dibujo técnico" /><span class="visually-hidden">Análisis de redes temporal en R
# </span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# Alex Brey </h3>
#   <a href="/es/lecciones/analisis-temporal-red"><h2 class="title">Análisis de redes temporal en R
# </h2></a>
#
#   <p class="abstract">
#     Aprende a utilizar R para analizar cómo cambian las redes a lo largo del tiempo.
#
#   </p>
#
#
#   <span class="activity">analyzing</span>
#   <span class="topics">network-analysis r</span>
#   <span class="date">2019-04-23</span>
#   <span class="difficulty">3</span>
#   <span id="/es/lecciones/analisis-temporal-red-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/analisis-temporal-red-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/analisis-voyant-tools"><img class="rounded" src="/gallery/analisis-voyant-tools.png" alt="Grafas con diferentes graduaciones de oftanmología" /><span class="visually-hidden">Análisis de corpus con Voyant Tools
# </span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# Silvia Gutiérrez De la Torre </h3>
#   <a href="/es/lecciones/analisis-voyant-tools"><h2 class="title">Análisis de corpus con Voyant Tools
# </h2></a>
#
#   <p class="abstract">
#     En este tutorial se aprenderá cómo organizar y analizar un conjunto de textos con Voyant-Tools.
#
#   </p>
#
#
#   <span class="activity">analyzing</span>
#   <span class="topics">distant-reading</span>
#   <span class="date">2019-04-20</span>
#   <span class="difficulty">1</span>
#   <span id="/es/lecciones/analisis-voyant-tools-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/analisis-voyant-tools-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/construir-repositorio-de-fuentes"><img class="rounded" src="/gallery/construir-repositorio-de-fuentes.png" alt="Personas mirando libros en una librería" /><span class="visually-hidden">Construir un repositorio de fuentes históricas con Omeka Classic
# </span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# Jairo Antonio Melo Flórez </h3>
#   <a href="/es/lecciones/construir-repositorio-de-fuentes"><h2 class="title">Construir un repositorio de fuentes históricas con Omeka Classic
# </h2></a>
#
#   <p class="abstract">
#     Esta lección profundiza en algunos aspectos avanzados de Omeka Classic con los cuales se facilita el control, administración y personalización del sistema para el desarrollo de repositorios de fuentes históricas.
#
#   </p>
#
#
#   <span class="activity">presenting</span>
#   <span class="topics">website</span>
#   <span class="date">2020-03-30</span>
#   <span class="difficulty">2</span>
#   <span id="/es/lecciones/construir-repositorio-de-fuentes-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/construir-repositorio-de-fuentes-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/contar-frecuencias"><img class="rounded" src="/gallery/counting-frequencies.png" alt="Boceto de un hombre sentado fumando una pipa y pájaros alrededor" /><span class="visually-hidden">Contar frecuencias de palabras con Python</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# William J. Turkel y Adam Crymble </h3>
#   <a href="/es/lecciones/contar-frecuencias"><h2 class="title">Contar frecuencias de palabras con Python</h2></a>
#
#   <p class="abstract">
#     Contar la frecuencia de palabras específicas en una lista puede proveer datos ilustrativos. Con esta lección aprenderás una forma fácil para contar dichas frecuencias usando Python.
#
#   </p>
#
#
#   <span class="activity">analyzing</span>
#   <span class="topics">python</span>
#   <span class="date">2017-03-15</span>
#   <span class="difficulty">2</span>
#   <span id="/es/lecciones/contar-frecuencias-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/contar-frecuencias-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/corpus-paralelo-lfaligner"><img class="rounded" src="/gallery/corpus-paralelo-lfaligner.png" alt="Grabado con tres mujeres" /><span class="visually-hidden">Creación de corpus paralelo con LF Aligner
# </span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# Armando Luza </h3>
#   <a href="/es/lecciones/corpus-paralelo-lfaligner"><h2 class="title">Creación de corpus paralelo con LF Aligner
# </h2></a>
#
#   <p class="abstract">
#     Esta lección enseña a crear corpus con traducciones a distintas lenguas, de forma que queden perfectamente alineados para una mejor visualización y consulta.
#
#   </p>
#
#
#   <span class="activity">analyzing</span>
#   <span class="topics">distant-reading</span>
#   <span class="date">2019-04-01</span>
#   <span class="difficulty">2</span>
#   <span id="/es/lecciones/corpus-paralelo-lfaligner-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/corpus-paralelo-lfaligner-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/creacion-de-aplicacion-shiny"><img class="rounded" src="/gallery/shiny-leaflet-newspaper-map-tutorial.png" alt="Barco y reflejo de la luna en un lago" /><span class="visually-hidden">Creación de aplicaciones web interactivas con R y Shiny</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# Yann Ryan </h3>
#   <a href="/es/lecciones/creacion-de-aplicacion-shiny"><h2 class="title">Creación de aplicaciones web interactivas con R y Shiny</h2></a>
#
#   <p class="abstract">
#     Esta lección demuestra cómo crear un mapa web interactivo usando R y Shiny. En la lección, diseñarás e implementarás una aplicación simple, que consiste en un control deslizante que permite a los usuarios seleccionar un rango de fechas y mostrar un conjunto de puntos correspondientes en un mapa interactivo.
#
#   </p>
#
#
#   <span class="activity">presenting</span>
#   <span class="topics">mapping website r</span>
#   <span class="date">2023-04-26</span>
#   <span class="difficulty">2</span>
#   <span id="/es/lecciones/creacion-de-aplicacion-shiny-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/creacion-de-aplicacion-shiny-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/creando-diagramas-de-redes-desde-fuentes-historicas"><img class="rounded" src="/gallery/creating-network-diagrams-from-historical-sources.png" alt="Diagrama circular con puntos cardinales" /><span class="visually-hidden">De la hermenéutica a las redes de datos: Extracción de datos y visualización de redes en fuentes históricas</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# Marten Düring </h3>
#   <a href="/es/lecciones/creando-diagramas-de-redes-desde-fuentes-historicas"><h2 class="title">De la hermenéutica a las redes de datos: Extracción de datos y visualización de redes en fuentes históricas</h2></a>
#
#   <p class="abstract">
#     La visualizaciones de redes pueden ayudar a los humanistas a revelar patrones complejos escondidos y estructuras en fuentes textuales. Este tutorial explica cómo extraer datos en red (personas, instituciones, lugares, etcétera.) de fuentes históricas a través del uso de métodos no especializados desarrollados en el marco del análisis de datos qualitativos (Qualitative Data Analysis, QDA) y el análisis de redes sociales (Social Network Analysis, SNA), y cómo visualizar estos datos con Palladio, una aplicación independiente de plataforma y que es particularmente fácil de usar.
#
#   </p>
#
#
#   <span class="activity">transforming</span>
#   <span class="topics">network-analysis</span>
#   <span class="date">2017-04-26</span>
#   <span class="difficulty">2</span>
#   <span id="/es/lecciones/creando-diagramas-de-redes-desde-fuentes-historicas-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/creando-diagramas-de-redes-desde-fuentes-historicas-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/crear-exposicion-con-omeka"><img class="rounded" src="/gallery/creating-an-omeka-exhibit.png" alt="Fotografía en blanco y negro de un salón con múltiples retratos en las paredes" /><span class="visually-hidden">Crear una exposición con Omeka</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# Miriam Posner y Megan R. Brett </h3>
#   <a href="/es/lecciones/crear-exposicion-con-omeka"><h2 class="title">Crear una exposición con Omeka</h2></a>
#
#   <p class="abstract">
#     Ahora que has agregado los artículos a tu sitio Omeka y los agrupaste por colecciones, estás listo para el paso siguiente: llevar a tus usuarios a un tour guiado por los artículos coleccionados.
#
#   </p>
#
#
#   <span class="activity">presenting</span>
#   <span class="topics">website</span>
#   <span class="date">2018-04-23</span>
#   <span class="difficulty">1</span>
#   <span id="/es/lecciones/crear-exposicion-con-omeka-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/crear-exposicion-con-omeka-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/crear-y-ver-archivos-html-con-python"><img class="rounded" src="/gallery/creating-and-viewing-html-files-with-python.png" alt="Grabado en blanco y negro de un niño sentado en un taburete sujetando un dibujo de una persona con una espada." /><span class="visually-hidden">Crear y ver archivos HTML con Python</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# William J. Turkel y Adam Crymble </h3>
#   <a href="/es/lecciones/crear-y-ver-archivos-html-con-python"><h2 class="title">Crear y ver archivos HTML con Python</h2></a>
#
#   <p class="abstract">
#     Aquí aprenderás cómo crear archivos HTML con scripts de Python, y cómo utilizar Python para abrir un archivo HTML en Firefox.
#
#   </p>
#
#
#   <span class="activity">presenting</span>
#   <span class="topics">python website</span>
#   <span class="date">2017-03-15</span>
#   <span class="difficulty">2</span>
#   <span id="/es/lecciones/crear-y-ver-archivos-html-con-python-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/crear-y-ver-archivos-html-con-python-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/datos-de-investigacion-con-unix"><img class="rounded" src="/gallery/research-data-with-unix.png" alt="Grabado en blanco y negro de un minero trabajando sobre una plataforma adentro de una mina." /><span class="visually-hidden">Contabilizar y minar datos de investigación con Unix</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# James Baker y Ian Milligan </h3>
#   <a href="/es/lecciones/datos-de-investigacion-con-unix"><h2 class="title">Contabilizar y minar datos de investigación con Unix</h2></a>
#
#   <p class="abstract">
#     En esta lección aprenderás cómo los datos de tu investigación pueden ser contados y extraídos mediante el shell Unix, cuando están organizados de manera clara y predecible.
#
#   </p>
#
#
#   <span class="activity">transforming</span>
#   <span class="topics">data-manipulation</span>
#   <span class="date">2017-10-14</span>
#   <span class="difficulty">2</span>
#   <span id="/es/lecciones/datos-de-investigacion-con-unix-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/datos-de-investigacion-con-unix-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/datos-tabulares-en-r"><img class="rounded" src="/gallery/r-basics-with-tabular-data.png" alt="Grabado de la letra r al estilo de letra iluminada." /><span class="visually-hidden">Datos tabulares en R</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# Taryn Dewar </h3>
#   <a href="/es/lecciones/datos-tabulares-en-r"><h2 class="title">Datos tabulares en R</h2></a>
#
#   <p class="abstract">
#     Esta lección te enseña una forma rápida de analizar grandes cantidades de datos en forma de tabla, haciendo la investigación más rápida y efectiva.
#
#   </p>
#
#
#   <span class="activity">transforming</span>
#   <span class="topics">data-manipulation r</span>
#   <span class="date">2018-08-20</span>
#   <span class="difficulty">1</span>
#   <span id="/es/lecciones/datos-tabulares-en-r-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/datos-tabulares-en-r-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/de-html-a-lista-de-palabras-1"><img class="rounded" src="/gallery/from-html-to-list-of-words-1.png" alt="Grabado de una jirafa de perfil mirando a un hombre también de perfil parado sujetando muletas para simular la postura de la jirafa." /><span class="visually-hidden">De HTML a lista de palabras (parte 1)</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# William J. Turkel y Adam Crymble </h3>
#   <a href="/es/lecciones/de-html-a-lista-de-palabras-1"><h2 class="title">De HTML a lista de palabras (parte 1)</h2></a>
#
#   <p class="abstract">
#     En esta lección en dos partes partiremos de lo que has aprendido sobre Descargar páginas web con Python, para aprender cómo remover las etiquetas HTML de la página web de la transcripción del juicio criminal contra Benjamin Bowsey de 1780. Lograremos esto utilizando una variedad de operadores de cadenas, métodos de cadenas y habilidades de lectura cercana. Vamos a presentar bucles (looping) y condicionales (branching), de manera que los programas puedan repetir tareas y pruebas para ciertas condiciones, haciendo posible separar el contenido de las etiquetas HTML. Por último, convertimos el contenido de una cadena larga a una lista de palabras que posteriormente podrán ser ordenadas, indexadas y contadas.
#
#   </p>
#
#
#   <span class="activity">transforming</span>
#   <span class="topics">python</span>
#   <span class="date">2017-03-15</span>
#   <span class="difficulty">2</span>
#   <span id="/es/lecciones/de-html-a-lista-de-palabras-1-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/de-html-a-lista-de-palabras-1-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/de-html-a-lista-de-palabras-2"><img class="rounded" src="/gallery/from-html-to-list-of-words-2.png" alt="Grabado de un hombre vestido de militar y otro hombre por detrás del primero que parece tener la intención de tropezarlo." /><span class="visually-hidden">De HTML a lista de palabras (parte 2)</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# William J. Turkel y Adam Crymble </h3>
#   <a href="/es/lecciones/de-html-a-lista-de-palabras-2"><h2 class="title">De HTML a lista de palabras (parte 2)</h2></a>
#
#   <p class="abstract">
#     En esa lección aprenderás los comandos de Python que son necesarios para implementar la segunda parte del algoritmo que comenzamos en la lección ‘De HTML a lista de palabras (parte 1)’.
#
#   </p>
#
#
#   <span class="activity">transforming</span>
#   <span class="topics">python</span>
#   <span class="date">2017-03-15</span>
#   <span class="difficulty">2</span>
#   <span id="/es/lecciones/de-html-a-lista-de-palabras-2-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/de-html-a-lista-de-palabras-2-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/descarga-automatizada-con-wget"><img class="rounded" src="/gallery/automated-downloading-with-wget.png" alt="Grabado de dos mineros dentro de una mina empujando carretillas hasta un ascensor." /><span class="visually-hidden">Descarga automatizada con Wget</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# Ian Milligan </h3>
#   <a href="/es/lecciones/descarga-automatizada-con-wget"><h2 class="title">Descarga automatizada con Wget</h2></a>
#
#   <p class="abstract">
#     Wget es un programa útil que se ejecuta a través de la línea de comandos de tu computadora. Sirve para recuperar material en línea.
#
#   </p>
#
#
#   <span class="activity">acquiring</span>
#   <span class="topics">web-scraping</span>
#   <span class="date">2018-11-29</span>
#   <span class="difficulty">1</span>
#   <span id="/es/lecciones/descarga-automatizada-con-wget-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/descarga-automatizada-con-wget-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/descarga-multiples-registros-usando-cadenas-de-consulta"><img class="rounded" src="/gallery/downloading-multiple-records-using-query-strings.png" alt="Figuras trabajando en una mina, empujando carros" /><span class="visually-hidden">Descargar múltiples registros mediante cadenas de consulta</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# Adam Crymble </h3>
#   <a href="/es/lecciones/descarga-multiples-registros-usando-cadenas-de-consulta"><h2 class="title">Descargar múltiples registros mediante cadenas de consulta</h2></a>
#
#   <p class="abstract">
#     Descargar un solo registro de un sitio web es fácil, aunque la descarga de muchos registros a la vez –una necesidad cada vez más frecuente– es mucho más eficiente utilizando un lenguaje de programación como Python. En esta lección escribiremos un programa que descargará una serie de registros del Old Bailey Online usando criterios de búsqueda personalizada y los guardará en un directorio de nuestro equipo.
#
#   </p>
#
#
#   <span class="activity">acquiring</span>
#   <span class="topics">web-scraping python</span>
#   <span class="date">2022-07-30</span>
#   <span class="difficulty">2</span>
#   <span id="/es/lecciones/descarga-multiples-registros-usando-cadenas-de-consulta-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/descarga-multiples-registros-usando-cadenas-de-consulta-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/editar-audio-con-audacity"><img class="rounded" src="/gallery/editing-audio-with-audacity.png" alt="Grabado de un fonógrafo y un gramófono." /><span class="visually-hidden">Editar audio con Audacity</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# Brandon Walsh </h3>
#   <a href="/es/lecciones/editar-audio-con-audacity"><h2 class="title">Editar audio con Audacity</h2></a>
#
#   <p class="abstract">
#     Con esta lección aprenderás a utilizar Audacity para cargar, editar, mezclar y exportar archivos de audio.
#
#   </p>
#
#
#   <span class="activity">transforming</span>
#   <span class="topics">data-manipulation</span>
#   <span class="date">2017-09-27</span>
#   <span class="difficulty">1</span>
#   <span id="/es/lecciones/editar-audio-con-audacity-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/editar-audio-con-audacity-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/escritura-sostenible-usando-pandoc-y-markdown"><img class="rounded" src="/gallery/sustainable-authorship-in-plain-text-using-pandoc-and-markdown.png" alt="Hombre leyendo y escribiendo en un escritorio" /><span class="visually-hidden">Escritura sostenible en texto plano usando Pandoc y Markdown</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# Dennis Tenen y Grant Wythoff </h3>
#   <a href="/es/lecciones/escritura-sostenible-usando-pandoc-y-markdown"><h2 class="title">Escritura sostenible en texto plano usando Pandoc y Markdown</h2></a>
#
#   <p class="abstract">
#     En este tutorial aprenderás lo básico de Markdown—una sintaxis de marcado para texto plano que es fácil de leer y de escribir así como Pandoc, una herramienta de línea de comandos que convierte el texto plano en varios tipos de archivos bellamente formateados: PDF, .docx, HTML, LaTeX, presentaciones de diapositivas y más.
#
#   </p>
#
#
#   <span class="activity">sustaining</span>
#   <span class="topics">website data-management</span>
#   <span class="date">2017-04-04</span>
#   <span class="difficulty">2</span>
#   <span id="/es/lecciones/escritura-sostenible-usando-pandoc-y-markdown-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/escritura-sostenible-usando-pandoc-y-markdown-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/exhibicion-con-collection-builder"><img class="rounded" src="/gallery/exhibicion-con-collection-builder.png" alt="Interior de una sala de museo antiguo." /><span class="visually-hidden">Exhibición digital mínima e interactiva con CollectionBuilder</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# Jennifer Isasi </h3>
#   <a href="/es/lecciones/exhibicion-con-collection-builder"><h2 class="title">Exhibición digital mínima e interactiva con CollectionBuilder</h2></a>
#
#   <p class="abstract">
#     En esta lección aprenderás a utilizar la versión ligera de CollectionBuilder para publicar una colección digital.
#
#   </p>
#
#
#   <span class="activity">presenting</span>
#   <span class="topics">website</span>
#   <span class="date">2022-08-21</span>
#   <span class="difficulty">2</span>
#   <span id="/es/lecciones/exhibicion-con-collection-builder-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/exhibicion-con-collection-builder-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/generadores-aventura"><img class="rounded" src="/gallery/generadores-aventura.png" alt="Imagen en blanco y negro que muestra un collage generado con esta lección y que incluye la imagen de un paisaje, una iglesia y dos vaqueros" /><span class="visually-hidden">Generadores de texto e imágenes usando gramáticas libres de contexto en Aventura.js</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# Sergio Rodríguez Gómez </h3>
#   <a href="/es/lecciones/generadores-aventura"><h2 class="title">Generadores de texto e imágenes usando gramáticas libres de contexto en Aventura.js</h2></a>
#
#   <p class="abstract">
#     Esta lección te enseña a crear generadores de texto e imágenes usando la librería Aventura.js para el lenguaje de programación JavaScript
#
#   </p>
#
#
#   <span class="activity">transforming</span>
#   <span class="topics">creative-coding</span>
#   <span class="date">2023-07-28</span>
#   <span class="difficulty">2</span>
#   <span id="/es/lecciones/generadores-aventura-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/generadores-aventura-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/georreferenciar-qgis"><img class="rounded" src="/gallery/georeferencing-qgis.png" alt="Mapa de una ciudad de montaña" /><span class="visually-hidden">Georreferenciar con QGIS 2.0
# </span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# Jim Clifford, Josh MacFadyen, y Daniel Macfarlane </h3>
#   <a href="/es/lecciones/georreferenciar-qgis"><h2 class="title">Georreferenciar con QGIS 2.0
# </h2></a>
#
#   <p class="abstract">
#     En esta lección aprenderás cómo georreferenciar mapas históricos para que puedan añadirse a un SIG (Sistema de Información Geográfica) como una capa ráster.
#
#   </p>
#
#
#   <span class="activity">transforming</span>
#   <span class="topics">mapping</span>
#   <span class="date">2020-06-05</span>
#   <span class="difficulty">2</span>
#   <span id="/es/lecciones/georreferenciar-qgis-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/georreferenciar-qgis-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/instalacion-linux"><img class="rounded" src="/gallery/linux-installation.png" alt="Tres hombres tocando instrumentos musicales" /><span class="visually-hidden">Creación de un entorno de desarrollo integrado para Python (Linux)</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# William J. Turkel y Adam Crymble </h3>
#   <a href="/es/lecciones/instalacion-linux"><h2 class="title">Creación de un entorno de desarrollo integrado para Python (Linux)</h2></a>
#
#   <p class="abstract">
#     Este tutorial te ayudará a configurar un entorno de desarrollo integrado para Python en un computador con el sistema operativo de Linux.
#
#   </p>
#
#
#   <span class="activity">transforming</span>
#   <span class="topics">get-ready python</span>
#   <span class="date">2017-03-15</span>
#   <span class="difficulty">1</span>
#   <span id="/es/lecciones/instalacion-linux-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/instalacion-linux-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/instalacion-mac"><img class="rounded" src="/gallery/mac-installation.png" alt="Tres hombres tocando instrumentos musicales" /><span class="visually-hidden">Creación de un entorno de desarrollo integrado para Python (Mac)</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# William J. Turkel y Adam Crymble </h3>
#   <a href="/es/lecciones/instalacion-mac"><h2 class="title">Creación de un entorno de desarrollo integrado para Python (Mac)</h2></a>
#
#   <p class="abstract">
#     Este tutorial te ayudará a configurar un entorno de desarrollo integrado para Python en un computador con el sistema operativo de Apple.
#
#   </p>
#
#
#   <span class="activity">transforming</span>
#   <span class="topics">get-ready python</span>
#   <span class="date">2017-03-15</span>
#   <span class="difficulty">1</span>
#   <span id="/es/lecciones/instalacion-mac-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/instalacion-mac-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/instalacion-windows"><img class="rounded" src="/gallery/windows-installation.png" alt="Tres hombres tocando instrumentos musicales" /><span class="visually-hidden">Creación de un entorno de desarrollo integrado para Python (Windows)</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# William J. Turkel y Adam Crymble </h3>
#   <a href="/es/lecciones/instalacion-windows"><h2 class="title">Creación de un entorno de desarrollo integrado para Python (Windows)</h2></a>
#
#   <p class="abstract">
#     Este tutorial te ayudará a configurar un entorno de desarrollo integrado para Python en un computador con el sistema operativo de Windows.
#
#   </p>
#
#
#   <span class="activity">transforming</span>
#   <span class="topics">get-ready python</span>
#   <span class="date">2017-03-15</span>
#   <span class="difficulty">1</span>
#   <span id="/es/lecciones/instalacion-windows-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/instalacion-windows-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
# ...
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/reutilizando-colecciones-digitales-glam-labs"><img class="rounded" src="/gallery/reutilizando-colecciones-digitales-glam-labs.png" alt="Grabado que muestra a tres personas trabajando en un laboratorio alquímico" /><span class="visually-hidden">Reutilizar colecciones digitales: GLAM Labs</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# Gustavo Candela, María Dolores Sáez, María Pilar Escobar, y Manuel Marco Such </h3>
#   <a href="/es/lecciones/reutilizando-colecciones-digitales-glam-labs"><h2 class="title">Reutilizar colecciones digitales: GLAM Labs</h2></a>
#
#   <p class="abstract">
#     Esta lección muestra cómo reutilizar colecciones digitales publicadas por instituciones de patrimonio cultural.
#
#   </p>
#
#
#   <span class="activity">transforming</span>
#   <span class="topics">data-manipulation python lod</span>
#   <span class="date">2021-08-30</span>
#   <span class="difficulty">3</span>
#   <span id="/es/lecciones/reutilizando-colecciones-digitales-glam-labs-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/reutilizando-colecciones-digitales-glam-labs-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/salida-de-datos-como-archivo-html"><img class="rounded" src="/gallery/output-data-as-html-file.png" alt="Grabado de mujer y dos niños." /><span class="visually-hidden">Salida de datos como archivo HTML con Python</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# William J. Turkel y Adam Crymble </h3>
#   <a href="/es/lecciones/salida-de-datos-como-archivo-html"><h2 class="title">Salida de datos como archivo HTML con Python</h2></a>
#
#   <p class="abstract">
#     Esta lección toma los pares de frecuencia creados en ‘Contar frecuencias de palabras con Python’ y crea una salida de datos a un archivo HTML.
#
#   </p>
#
#
#   <span class="activity">transforming</span>
#   <span class="topics">python website</span>
#   <span class="date">2017-03-15</span>
#   <span class="difficulty">2</span>
#   <span id="/es/lecciones/salida-de-datos-como-archivo-html-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/salida-de-datos-como-archivo-html-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/salida-palabras-clave-contexto-ngrams"><img class="rounded" src="/gallery/output-keywords-in-context-in-html-file.png" alt="Grabado de un león, un oso y un mono caminando." /><span class="visually-hidden">Salida de palabras clave en contexto en un archivo HTML con Python</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# William J. Turkel y Adam Crymble </h3>
#   <a href="/es/lecciones/salida-palabras-clave-contexto-ngrams"><h2 class="title">Salida de palabras clave en contexto en un archivo HTML con Python</h2></a>
#
#   <p class="abstract">
#     Esta lección se basa en ‘Palabras clave en contexto (usando n-grams)’, en la que se extrajeron n-gramas de un texto. Aquí aprenderás cómo generar una salidad de todos los n-gramas de una palabra clave dada en un documento descargado de Internet, y visualizarlos claramente en la ventana de tu navegador.
#
#   </p>
#
#
#   <span class="activity">presenting</span>
#   <span class="topics">python</span>
#   <span class="date">2017-03-15</span>
#   <span class="difficulty">2</span>
#   <span id="/es/lecciones/salida-palabras-clave-contexto-ngrams-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/salida-palabras-clave-contexto-ngrams-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/sitios-estaticos-con-jekyll-y-github-pages"><img class="rounded" src="/gallery/building-static-sites-with-jekyll-github-pages.png" alt="Una ilustración del Dr. Jekyll transformándose en Mr. Hyde" /><span class="visually-hidden">Creación de sitios estáticos con Jekyll y GitHub Pages</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# Amanda Visconti </h3>
#   <a href="/es/lecciones/sitios-estaticos-con-jekyll-y-github-pages"><h2 class="title">Creación de sitios estáticos con Jekyll y GitHub Pages</h2></a>
#
#   <p class="abstract">
#     Esta lección te ayudará a crear un sitio web seguro completamente gratuito, fácil de mantener y sobre el que tendrás control total, como un blog académico, un sitio web de proyectos o un portafolio en línea.
#
#   </p>
#
#
#   <span class="activity">presenting</span>
#   <span class="topics">website data-management</span>
#   <span class="date">2021-03-01</span>
#   <span class="difficulty">1</span>
#   <span id="/es/lecciones/sitios-estaticos-con-jekyll-y-github-pages-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/sitios-estaticos-con-jekyll-y-github-pages-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/topic-modeling-y-mallet"><img class="rounded" src="/gallery/topic-modeling-and-mallet.png" alt="Ilustración de un herrero trabajando." /><span class="visually-hidden">Introducción a Topic Modeling y MALLET</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# Shawn Graham, Scott Weingart, y Ian Milligan </h3>
#   <a href="/es/lecciones/topic-modeling-y-mallet"><h2 class="title">Introducción a Topic Modeling y MALLET</h2></a>
#
#   <p class="abstract">
#     Esta lección explica qué es <em>topic modeling</em> y por qué podrías querer utilizarlo en tus investigaciones. Luego aprenderás cómo instalar y trabajar con MALLET, una caja de herramientas para procesamiento de lenguajes naturales (PLN) con la que <em>topic modeling</em> se puede llevar a la práctica.
#
#   </p>
#
#
#   <span class="activity">analyzing</span>
#   <span class="topics">distant-reading</span>
#   <span class="date">2018-10-31</span>
#   <span class="difficulty">2</span>
#   <span id="/es/lecciones/topic-modeling-y-mallet-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/topic-modeling-y-mallet-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/trabajar-con-archivos-de-texto"><img class="rounded" src="/gallery/working-with-text-files.png" alt="Dibujo de un señor leyendo el abecedario." /><span class="visually-hidden">Trabajar con archivos de texto en Python</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# William J. Turkel y Adam Crymble </h3>
#   <a href="/es/lecciones/trabajar-con-archivos-de-texto"><h2 class="title">Trabajar con archivos de texto en Python</h2></a>
#
#   <p class="abstract">
#     En esta lección aprenderás a manipular archivos de texto utilizando Python.
#
#   </p>
#
#
#   <span class="activity">transforming</span>
#   <span class="topics">python</span>
#   <span class="date">2017-03-15</span>
#   <span class="difficulty">2</span>
#   <span id="/es/lecciones/trabajar-con-archivos-de-texto-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/trabajar-con-archivos-de-texto-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/trabajar-con-paginas-web"><img class="rounded" src="/gallery/working-with-web-pages.png" alt="Grabado de una mujer y un hombre de pies." /><span class="visually-hidden">Descargar páginas web con Python</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# William J. Turkel y Adam Crymble </h3>
#   <a href="/es/lecciones/trabajar-con-paginas-web"><h2 class="title">Descargar páginas web con Python</h2></a>
#
#   <p class="abstract">
#     Esta lección muestra qué es un Localizador de recursos uniforme (Uniform Resource Locator = URL) y explica cómo utilizar Python para descargar y guardar los contenidos de una página web en tu disco duro.
#
#   </p>
#
#
#   <span class="activity">acquiring</span>
#   <span class="topics">python</span>
#   <span class="date">2017-03-15</span>
#   <span class="difficulty">2</span>
#   <span id="/es/lecciones/trabajar-con-paginas-web-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/trabajar-con-paginas-web-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/transformacion-datos-xml-xsl"><img class="rounded" src="/gallery/transforming-xml-with-xsl.png" alt="Dibujo de un pavo real con sus plumas extendidas." /><span class="visually-hidden">Transformación de datos con XML y XSL para su reutilización</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# M. H. Beals </h3>
#   <a href="/es/lecciones/transformacion-datos-xml-xsl"><h2 class="title">Transformación de datos con XML y XSL para su reutilización</h2></a>
#
#   <p class="abstract">
#     Con este tutorial aprenderás a convertir un conjunto de datos históricos procedentes de una base de datos XML (ya sea un solo documento o varios documentos interconectados) en otros formatos más adecuados para presentar (tablas, listas) o exponer información (párrafos).
#
#   </p>
#
#
#   <span class="activity">transforming</span>
#   <span class="topics">data-manipulation</span>
#   <span class="date">2018-08-02</span>
#   <span class="difficulty">1</span>
#   <span id="/es/lecciones/transformacion-datos-xml-xsl-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/transformacion-datos-xml-xsl-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/ver-archivos-html"><img class="rounded" src="/gallery/viewing-html-files.png" alt="Grabado de un hombre hablando a una mujer." /><span class="visually-hidden">Para entender páginas web y HTML</span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# William J. Turkel y Adam Crymble </h3>
#   <a href="/es/lecciones/ver-archivos-html"><h2 class="title">Para entender páginas web y HTML</h2></a>
#
#   <p class="abstract">
#     Esta lección te introduce a las estructuras de HTML y de páginas web.
#
#   </p>
#
#
#   <span class="activity">presenting</span>
#   <span class="topics">python</span>
#   <span class="date">2017-03-15</span>
#   <span class="difficulty">2</span>
#   <span id="/es/lecciones/ver-archivos-html-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/ver-archivos-html-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#
#     <li>
#
# <div class="lesson-description clearfix">
#
#
#   <div class="lesson-image">
#     <a href="/es/lecciones/visualizacion-y-animacion-de-tablas-historicas-con-R"><img class="rounded" src="/gallery/visualizacion-y-animacion-de-tablas-historicas-con-R.png" alt="Una mano llevando una botella." /><span class="visually-hidden">Visualización y animación de tablas históricas con R
# </span></a>
#   </div>
#
#   <h3 class="above-title">
#
#
#
# Marcelo Raimundo </h3>
#   <a href="/es/lecciones/visualizacion-y-animacion-de-tablas-historicas-con-R"><h2 class="title">Visualización y animación de tablas históricas con R
# </h2></a>
#
#   <p class="abstract">
#     En esta lección aprenderás a visualizar y animar temporalmente datos históricos almacenados en forma de tabla.
#
#   </p>
#
#
#   <span class="activity">analyzing</span>
#   <span class="topics">distant-reading r</span>
#   <span class="date">2021-06-28</span>
#   <span class="difficulty">2</span>
#   <span id="/es/lecciones/visualizacion-y-animacion-de-tablas-historicas-con-R-score" class="score" style="display: none;">0</span>
#   <p id="/es/lecciones/visualizacion-y-animacion-de-tablas-historicas-con-R-search_results" class="search_results" style="display: none;"></p>
#
#
#
# </div>
# </li>
#
#   </ul>
#
# </div>
#
# <script src="//cdnjs.cloudflare.com/ajax/libs/jquery/2.1.3/jquery.min.js"></script>
#
# <script src="//cdnjs.cloudflare.com/ajax/libs/list.js/1.5.0/list.min.js"></script>
#
# <script src="/js/URI.min.js"></script>
#
# <script src="https://unpkg.com/lunr/lunr.js"></script>
#
# <script src="/js/vendor/lunr.stemmer.support.js"></script>
#
# <script src="/js/vendor/lunr.es.js"></script>
#
# <script src="/js/lessonfilter.js"></script>
#
# <script>
#   $(function () {
#     wireButtons();
#   });
# </script>
#
#
#       </article>
#     </div>
#
#
#
# <footer role="contentinfo" style="background-color: #535D7F">
#
#
# <div class="d-flex flex-wrap justify-content-center footer-head">
#   <p><em>The Programming Historian en español</em> (ISSN: 2517-5769) se publica con una licencia <a href="https://creativecommons.org/licenses/by/4.0/deed.es">CC-BY</a>.</p>
# <p>Este proyecto es administrado por ProgHist Ltd, organización benéfica número <a href="https://register-of-charities.charitycommission.gov.uk/charity-search/-/charity-details/5181272/charity-overview">1195875</a> y número de compañía <a href="https://find-and-update.company-information.service.gov.uk/company/12192946">12192946</a>.</p>
#
# </div>
#
# <div class="d-flex flex-wrap justify-content-around">
#   <div class="mx-4">
#
#       <p>
#         <a href="/">ISSN 2397-2068 (inglés)</a>
#       </p>
#
#     <strong>
#       <p>
#         <a href="/es">ISSN 2517-5769 (español)</a>
#       </p>
#       </strong>
#       <p>
#         <a href="/fr">ISSN 2631-9462 (francés)</a>
#       </p>
#
#       <p>
#         <a href="/pt">ISSN 2753-9296 (portugués)</a>
#       </p>
#
#   </div>
#   <div class="mx-4">
#     <i class="fab fa-github" aria-hidden="true"></i>
#     <a href="https://github.com/programminghistorian/jekyll">Alojado en GitHub</a>
#   </div>
#
#   <div class="mx-4">
#   <i class="fa fa-calendar" aria-hidden="true"></i>
#     <a href="https://github.com/programminghistorian/jekyll/commits/gh-pages">Última actualización el 13 October 2023</a>
#   </div>
#
#  <div class="mx-4">
#   <i class="fas fa-rss" aria-hidden="true"></i>
#   <a href="https://programminghistorian.org/feed.xml">Suscripción a RSS</a>
#   </div>
#
#   <div class="mx-4">
#   <i class="fa fa-history" aria-hidden="true"></i>
#   <a href="https://github.com/programminghistorian/jekyll/commits/gh-pages/es/lecciones.md">Versiones anteriores</a>
#   </div>
#
#   <div class="mx-4">
#   <i class="fa fa-bolt" aria-hidden="true"></i>
#   <a href="/es/retroalimentacion">Envíanos tus comentarios</a>
#   </div>
#
#   <div class="mx-4">
#   <i class="fa fa-chain-broken" aria-hidden="true"></i>
#   <a href="/es/politica-retirada-lecciones">Política de retiro de lecciones</a>
#   </div>
#
#   <div class="mx-4">
#   <i class="fa fa-globe" aria-hidden="true"></i>
#   <a href="/translation-concordance">Concordancia de traducción</a>
#   </div>
#
#   </div>
#
# </footer>
#
#
#
# <script type="text/javascript">
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-2752866-8']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
# </script>
#
# <!-- Google tag (gtag.js) -->
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-EWDPQ3Y674"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-EWDPQ3Y674');
# </script>
#
#
#
#   </body>
#
# </html>

# %%
# Extraer los datos que nos interesan

# probar qué pasa si trato de extraer las etiquetas que identificamos

elementos_h2 = soup.find_all("h2", class_ = "title")
len(elementos_h2)
elementos_h2[0].get_text()
elementos_h2[58].get_text()
# Out:
# 'Para entender páginas web y HTML'

# %%
todos_los_enlaces = soup.find_all("a")
len(todos_los_enlaces)

for enlace in todos_los_enlaces:
    print(enlace.get("href"))
# Out:
# https://www.patreon.com/theprogramminghistorian
# /es
# None
# /es/acerca-de
# /es/equipo-de-proyecto
# /es/investigacion
# /es/vacantes
# /es/politica-de-privacidad
# None
# /es/contribuciones
# /es/retroalimentacion
# /es/guia-para-revisores
# /es/guia-para-autores
# /es/guia-para-traductores
# /es/guia-editor
# https://github.com/programminghistorian/jekyll/wiki/Making-Technical-Contributions
# /es/lecciones
# /es/eventos
# None
# /es/pia
# /es/donaciones
# /es/colaboradores
# /blog
# /en/lessons/
# None
# /fr/lecons/
# /pt/licoes/
# /es/retroalimentacion
# https://lunrjs.com/guides/searching.html
# /es/lecciones/administracion-de-datos-en-r
# /es/lecciones/administracion-de-datos-en-r
# /es/lecciones/analisis-de-corpus-con-antconc
# /es/lecciones/analisis-de-corpus-con-antconc
# /es/lecciones/analisis-de-correspondencia-en-r
# /es/lecciones/analisis-de-correspondencia-en-r
# /es/lecciones/analisis-de-sentimientos-r
# /es/lecciones/analisis-de-sentimientos-r
# /es/lecciones/analisis-temporal-red
# /es/lecciones/analisis-temporal-red
# /es/lecciones/analisis-voyant-tools
# /es/lecciones/analisis-voyant-tools
# /es/lecciones/construir-repositorio-de-fuentes
# /es/lecciones/construir-repositorio-de-fuentes
# /es/lecciones/contar-frecuencias
# /es/lecciones/contar-frecuencias
# /es/lecciones/corpus-paralelo-lfaligner
# /es/lecciones/corpus-paralelo-lfaligner
# /es/lecciones/creacion-de-aplicacion-shiny
# /es/lecciones/creacion-de-aplicacion-shiny
# /es/lecciones/creando-diagramas-de-redes-desde-fuentes-historicas
# /es/lecciones/creando-diagramas-de-redes-desde-fuentes-historicas
# /es/lecciones/crear-exposicion-con-omeka
# /es/lecciones/crear-exposicion-con-omeka
# /es/lecciones/crear-y-ver-archivos-html-con-python
# /es/lecciones/crear-y-ver-archivos-html-con-python
# /es/lecciones/datos-de-investigacion-con-unix
# /es/lecciones/datos-de-investigacion-con-unix
# /es/lecciones/datos-tabulares-en-r
# /es/lecciones/datos-tabulares-en-r
# /es/lecciones/de-html-a-lista-de-palabras-1
# /es/lecciones/de-html-a-lista-de-palabras-1
# /es/lecciones/de-html-a-lista-de-palabras-2
# /es/lecciones/de-html-a-lista-de-palabras-2
# /es/lecciones/descarga-automatizada-con-wget
# /es/lecciones/descarga-automatizada-con-wget
# /es/lecciones/descarga-multiples-registros-usando-cadenas-de-consulta
# /es/lecciones/descarga-multiples-registros-usando-cadenas-de-consulta
# /es/lecciones/editar-audio-con-audacity
# /es/lecciones/editar-audio-con-audacity
# /es/lecciones/escritura-sostenible-usando-pandoc-y-markdown
# /es/lecciones/escritura-sostenible-usando-pandoc-y-markdown
# /es/lecciones/exhibicion-con-collection-builder
# /es/lecciones/exhibicion-con-collection-builder
# /es/lecciones/generadores-aventura
# /es/lecciones/generadores-aventura
# /es/lecciones/georreferenciar-qgis
# /es/lecciones/georreferenciar-qgis
# /es/lecciones/instalacion-linux
# /es/lecciones/instalacion-linux
# /es/lecciones/instalacion-mac
# /es/lecciones/instalacion-mac
# /es/lecciones/instalacion-windows
# /es/lecciones/instalacion-windows
# /es/lecciones/instalar-modulos-python-pip
# /es/lecciones/instalar-modulos-python-pip
# /es/lecciones/intro-a-google-maps-y-google-earth
# /es/lecciones/intro-a-google-maps-y-google-earth
# /es/lecciones/introduccion-a-bash
# /es/lecciones/introduccion-a-bash
# /es/lecciones/introduccion-a-ffmpeg
# /es/lecciones/introduccion-a-ffmpeg
# /es/lecciones/introduccion-a-imageplot-y-la-visualizacion-de-metadatos
# /es/lecciones/introduccion-a-imageplot-y-la-visualizacion-de-metadatos
# /es/lecciones/introduccion-a-markdown
# /es/lecciones/introduccion-a-markdown
# /es/lecciones/introduccion-a-powershell
# /es/lecciones/introduccion-a-powershell
# /es/lecciones/introduccion-a-tei-1
# /es/lecciones/introduccion-a-tei-1
# /es/lecciones/introduccion-a-tei-2
# /es/lecciones/introduccion-a-tei-2
# /es/lecciones/introduccion-al-web-scraping-usando-r
# /es/lecciones/introduccion-al-web-scraping-usando-r
# /es/lecciones/introduccion-datos-abiertos-enlazados
# /es/lecciones/introduccion-datos-abiertos-enlazados
# /es/lecciones/introduccion-e-instalacion
# /es/lecciones/introduccion-e-instalacion
# /es/lecciones/introduccion-map-warper
# /es/lecciones/introduccion-map-warper
# /es/lecciones/limpieza-de-datos-con-OpenRefine
# /es/lecciones/limpieza-de-datos-con-OpenRefine
# /es/lecciones/manipular-cadenas-de-caracteres-en-python
# /es/lecciones/manipular-cadenas-de-caracteres-en-python
# /es/lecciones/mineria-de-datos-en-internet-archive
# /es/lecciones/mineria-de-datos-en-internet-archive
# /es/lecciones/normalizar-datos
# /es/lecciones/normalizar-datos
# /es/lecciones/palabras-clave-en-contexto-n-grams
# /es/lecciones/palabras-clave-en-contexto-n-grams
# /es/lecciones/poniendo-omeka-a-funcionar
# /es/lecciones/poniendo-omeka-a-funcionar
# /es/lecciones/preservar-datos-de-investigacion
# /es/lecciones/preservar-datos-de-investigacion
# /es/lecciones/procesamiento-basico-de-textos-en-r
# /es/lecciones/procesamiento-basico-de-textos-en-r
# /es/lecciones/publicar-archivos-tei-ceteicean
# /es/lecciones/publicar-archivos-tei-ceteicean
# /es/lecciones/reutilizacion-de-codigo-y-modularidad
# /es/lecciones/reutilizacion-de-codigo-y-modularidad
# /es/lecciones/reutilizando-colecciones-digitales-glam-labs
# /es/lecciones/reutilizando-colecciones-digitales-glam-labs
# /es/lecciones/salida-de-datos-como-archivo-html
# /es/lecciones/salida-de-datos-como-archivo-html
# /es/lecciones/salida-palabras-clave-contexto-ngrams
# /es/lecciones/salida-palabras-clave-contexto-ngrams
# /es/lecciones/sitios-estaticos-con-jekyll-y-github-pages
# /es/lecciones/sitios-estaticos-con-jekyll-y-github-pages
# /es/lecciones/topic-modeling-y-mallet
# /es/lecciones/topic-modeling-y-mallet
# /es/lecciones/trabajar-con-archivos-de-texto
# /es/lecciones/trabajar-con-archivos-de-texto
# /es/lecciones/trabajar-con-paginas-web
# /es/lecciones/trabajar-con-paginas-web
# /es/lecciones/transformacion-datos-xml-xsl
# /es/lecciones/transformacion-datos-xml-xsl
# /es/lecciones/ver-archivos-html
# /es/lecciones/ver-archivos-html
# /es/lecciones/visualizacion-y-animacion-de-tablas-historicas-con-R
# /es/lecciones/visualizacion-y-animacion-de-tablas-historicas-con-R
# https://creativecommons.org/licenses/by/4.0/deed.es
# https://register-of-charities.charitycommission.gov.uk/charity-search/-/charity-details/5181272/charity-overview
# https://find-and-update.company-information.service.gov.uk/company/12192946
# /
# /es
# /fr
# /pt
# https://github.com/programminghistorian/jekyll
# https://github.com/programminghistorian/jekyll/commits/gh-pages
# https://programminghistorian.org/feed.xml
# https://github.com/programminghistorian/jekyll/commits/gh-pages/es/lecciones.md
# /es/retroalimentacion
# /es/politica-retirada-lecciones
# /translation-concordance

# %%
# Lo anterior nos devolvía más información de la que queríamos. Por lo tanto vamos a hacer un "recorte": vamos a extraer los datos de el div con la clase "lesson-description" y ahí dentro buscar lo que nos interesa

lista_lecciones = soup.find_all("div", class_ = "lesson-description")
len(lista_lecciones)
# Out:
# 60

# %%
lista_lecciones[41]
# Out:
# <div class="lesson-description clearfix">
# <div class="lesson-image">
# <a href="/es/lecciones/manipular-cadenas-de-caracteres-en-python"><img alt="Grabado de un joven tocando una guitarra" class="rounded" src="/gallery/manipulating-strings-in-python.png"/><span class="visually-hidden">Manipular cadenas de caracteres en Python</span></a>
# </div>
# <h3 class="above-title">
#
#
#
# William J. Turkel y Adam Crymble </h3>
# <a href="/es/lecciones/manipular-cadenas-de-caracteres-en-python"><h2 class="title">Manipular cadenas de caracteres en Python</h2></a>
# <p class="abstract">
#     Esta lección es una rápida introducción a técnicas de manipulación de cadenas de caracteres (o strings) en Python.
#
#   </p>
# <span class="activity">transforming</span>
# <span class="topics">python</span>
# <span class="date">2017-03-15</span>
# <span class="difficulty">2</span>
# <span class="score" id="/es/lecciones/manipular-cadenas-de-caracteres-en-python-score" style="display: none;">0</span>
# <p class="search_results" id="/es/lecciones/manipular-cadenas-de-caracteres-en-python-search_results" style="display: none;"></p>
# </div>

# %%
# titulo
lista_lecciones[41].h2.get_text()
# Out:
# 'Manipular cadenas de caracteres en Python'

# %%
# autores
lista_lecciones[41].h3.get_text(strip = True)
# Out:
# 'William J. Turkel y Adam Crymble'

# %%
# enlace
lista_lecciones[41].a.get("href")
# Out:
# '/es/lecciones/manipular-cadenas-de-caracteres-en-python'

# %%
# descripcion
lista_lecciones[41].p.get_text(strip = True)
# Out:
# 'Esta lección es una rápida introducción a técnicas de manipulación de cadenas de caracteres (o strings) en Python.'

# %%
# date
lista_lecciones[41].find("span", class_ = "date").get_text()
# Out:
# '2017-03-15'

# %%
# topics

lista_lecciones[41].find("span", class_ = "topics").get_text()
lista_lecciones[2].find("span", class_ = "topics").get_text().split()
# Out:
# ['data-manipulation', 'network-analysis', 'r']

# %%
# Ahora que ya exploramos la página, hagamos la extracción:

titulos = []
topicos = []
enlaces = []

for leccion in lista_lecciones:
    # extremos el título y lo guardamos en la lista títulos
    titulo = leccion.h2.get_text(strip = True)
    titulos.append(titulo)

    # extraemos los tópicos y los guardamos en la lista tópicos
    topico = leccion.find("span", class_ = "topics").get_text().split()
    topicos.append(topico)

    # extrer y guardar los enlaces
    enlace = leccion.a.get("href")
    enlaces.append(f"http://programminghistorian.org{enlace}")

# %%
# creamos un diccionario

tutoriales_ph = {"titulo": titulos, "topicos": topicos, "enlace": enlaces}

df_tutoriales_ph = pd.DataFrame(tutoriales_ph)

# %%
df_tutoriales_ph.head()
# Out:
#                                               titulo  \
# 0                       Administración de datos en R
# 1                     Análisis de corpus con AntConc
# 2  Análisis de correspondencia para la investigac...
# 3        Análisis de sentimientos en R con 'syuzhet'
# 4                    Análisis de redes temporal en R
#
#                                              topicos  \
# 0  [data-manipulation, data-management, distant-r...
# 1                                  [distant-reading]
# 2           [data-manipulation, network-analysis, r]
# 3                               [distant-reading, r]
# 4                              [network-analysis, r]
#
#                                               enlace
# 0  http://programminghistorian.org/es/lecciones/a...
# 1  http://programminghistorian.org/es/lecciones/a...
# 2  http://programminghistorian.org/es/lecciones/a...
# 3  http://programminghistorian.org/es/lecciones/a...
# 4  http://programminghistorian.org/es/lecciones/a...

# %%
df_tutoriales_ph.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   titulo   60 non-null     object
#  1   topicos  60 non-null     object
#  2   enlace   60 non-null     object
# dtypes: object(3)
# memory usage: 1.5+ KB

# %%
df_tutoriales_ph.to_csv("data/tutoriales_ph.csv", index = False)
