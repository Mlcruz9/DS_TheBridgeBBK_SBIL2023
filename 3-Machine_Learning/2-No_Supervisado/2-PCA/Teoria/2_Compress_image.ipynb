# %% [markdown]
# A typical digital image is made by stacking Red Blue and Green pixel arrays of intensities ranging from 0 to 255.

# %% [markdown]
# <img src="img/RGB.png">

# %% [markdown]
# A grayscale image does not contain color but only shades of gray. The pixel intensity in a grayscale image varies from black (0 intensity) to white (255 full intensity) to make it what we usually call as a Black & White image.

# %% [markdown]
# Digits dataset is a grayscale image dataset of handwritten digit having 1797 8×8 images.

# %%
#importing the dataset
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
 
digits = load_digits()
data = digits.data
data.shape
# Out:
# (1797, 64)

# %%
data[0]
# Out:
# array([ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.,  0.,  0., 13., 15., 10.,
#        15.,  5.,  0.,  0.,  3., 15.,  2.,  0., 11.,  8.,  0.,  0.,  4.,
#        12.,  0.,  0.,  8.,  8.,  0.,  0.,  5.,  8.,  0.,  0.,  9.,  8.,
#         0.,  0.,  4., 11.,  0.,  1., 12.,  7.,  0.,  0.,  2., 14.,  5.,
#        10., 12.,  0.,  0.,  0.,  0.,  6., 13., 10.,  0.,  0.,  0.])

# %% [markdown]
# sklearn.datasets module makes it quick to import digits data by importing load_digits class from it. The shape of the digit data is (1797, 64). 8×8 pixels are flattened to create a vector of length 64 for every image.

# %%
#taking a sample image to view
#Remember image is in the form of numpy array.
image_sample = data[0,:].reshape(8,8)
image_sample
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
plt.imshow(image_sample, cmap='binary')

# %% [markdown]
# Now, using PCA, let’s reduce the image dimensions from 64 to just 2 so that we can visualize the dataset using a Scatterplot.

# %%
from sklearn.decomposition import PCA

pca = PCA(2)
converted_data = pca.fit_transform(digits.data)

converted_data.shape
# Out:
# (1797, 2)

# %% [markdown]
# We can also pass a float value less than 1 instead of an integer number. i.e. PCA(0.90) this means the algorithm will find the principal components which explain 90% of the variance in data.

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize = (10,6))
c_map = plt.cm.get_cmap('jet', 10)
plt.scatter(converted_data[:, 0], converted_data[:, 1], s = 15,
            cmap = c_map , c = digits.target)
plt.colorbar()
plt.xlabel('PC-1') , plt.ylabel('PC-2')
plt.show();
# Out:
# C:\Users\misla\AppData\Local\Temp\ipykernel_7400\2678976809.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
# C:\Users\misla\AppData\Local\Temp\ipykernel_7400\2678976809.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   c_map = plt.cm.get_cmap('jet', 10)

# %% [markdown]
# Another cool application of PCA is in Image compression. Let’s have a look at how can we achieve this with python.

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\misla\.pyenv\pyenv-win\versions\3.10.2\lib\site-packages (from opencv-python) (1.23.5)
# Downloading opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl (38.1 MB)
#    ---------------------------------------- 0.0/38.1 MB ? eta -:--:--
#    ---------------------------------------- 0.2/38.1 MB 6.9 MB/s eta 0:00:06
#    ---------------------------------------- 0.2/38.1 MB 6.9 MB/s eta 0:00:06
#    ---------------------------------------- 0.2/38.1 MB 6.9 MB/s eta 0:00:06
#     --------------------------------------- 0.6/38.1 MB 2.9 MB/s eta 0:00:13
#    - -------------------------------------- 1.0/38.1 MB 4.1 MB/s eta 0:00:09
#    - -------------------------------------- 1.2/38.1 MB 4.4 MB/s eta 0:00:09
#    - -------------------------------------- 1.7/38.1 MB 5.1 MB/s eta 0:00:08
#    -- ------------------------------------- 2.0/38.1 MB 5.1 MB/s eta 0:00:08
#    -- ------------------------------------- 2.3/38.1 MB 5.3 MB/s eta 0:00:07
#    -- ------------------------------------- 2.3/38.1 MB 5.3 MB/s eta 0:00:07
#    -- ------------------------------------- 2.3/38.1 MB 5.3 MB/s eta 0:00:07
#    -- ------------------------------------- 2.5/38.1 MB 4.3 MB/s eta 0:00:09
#    -- ------------------------------------- 2.7/38.1 MB 4.3 MB/s eta 0:00:09
#    -- ------------------------------------- 2.7/38.1 MB 4.3 MB/s eta 0:00:09
#    -- ------------------------------------- 2.7/38.1 MB 4.3 MB/s eta 0:00:09
#    -- ------------------------------------- 2.8/38.1 MB 3.7 MB/s eta 0:00:10
#    --- ------------------------------------ 3.0/38.1 MB 3.8 MB/s eta 0:00:10
#    --- ------------------------------------ 3.0/38.1 MB 3.8 MB/s eta 0:00:10
#    --- ------------------------------------ 3.0/38.1 MB 3.8 MB/s eta 0:00:10
#    --- ------------------------------------ 3.2/38.1 MB 3.3 MB/s eta 0:00:11
#    --- ------------------------------------ 3.3/38.1 MB 3.3 MB/s eta 0:00:11
#    --- ------------------------------------ 3.5/38.1 MB 3.3 MB/s eta 0:00:11
#    --- ------------------------------------ 3.6/38.1 MB 3.3 MB/s eta 0:00:11
#    ---- ----------------------------------- 3.8/38.1 MB 3.3 MB/s eta 0:00:11
#    ---- ----------------------------------- 4.0/38.1 MB 3.3 MB/s eta 0:00:11
#    ---- ----------------------------------- 4.1/38.1 MB 3.4 MB/s eta 0:00:11
#    ---- ----------------------------------- 4.3/38.1 MB 3.4 MB/s eta 0:00:10
#    ---- ----------------------------------- 4.4/38.1 MB 3.4 MB/s eta 0:00:10
#    ---- ----------------------------------- 4.5/38.1 MB 3.2 MB/s eta 0:00:11
#    ---- ----------------------------------- 4.6/38.1 MB 3.3 MB/s eta 0:00:11
#    ----- ---------------------------------- 4.8/38.1 MB 3.3 MB/s eta 0:00:11
#    ----- ---------------------------------- 5
MB 3.1 MB/s eta 0:00:06
#    --------------------- ------------------ 20.8/38.1 MB 3.1 MB/s eta 0:00:06
#    ---------------------- ----------------- 21.0/38.1 MB 3.1 MB/s eta 0:00:06
#    ---------------------- ----------------- 21.1/38.1 MB 3.1 MB/s eta 0:00:06
#    ---------------------- ----------------- 21.3/38.1 MB 3.1 MB/s eta 0:00:06
#    ---------------------- ----------------- 21.5/38.1 MB 3.1 MB/s eta 0:00:06
#    ---------------------- ----------------- 21.7/38.1 MB 3.2 MB/s eta 0:00:06
#    ----------------------- ---------------- 21.9/38.1 MB 3.3 MB/s eta 0:00:05
#    ----------------------- ---------------- 22.1/38.1 MB 3.3 MB/s eta 0:00:05
#    ----------------------- ---------------- 22.2/38.1 MB 3.3 MB/s eta 0:00:05
#    ----------------------- ---------------- 22.2/38.1 MB 3.3 MB/s eta 0:00:05
#    ----------------------- ---------------- 22.2/38.1 MB 3.3 MB/s eta 0:00:05
#    ----------------------- ---------------- 22.4/38.1 MB 3.2 MB/s eta 0:00:05
#    ----------------------- ---------------- 22.5/38.1 MB 3.2 MB/s eta 0:00:05
#    ----------------------- ---------------- 22.7/38.1 MB 3.3 MB/s eta 0:00:05
#    ----------------------- ---------------- 22.8/38.1 MB 3.3 MB/s eta 0:00:05
#    ------------------------ --------------- 23.0/38.1 MB 3.4 MB/s eta 0:00:05
#    ------------------------ --------------- 23.2/38.1 MB 3.5 MB/s eta 0:00:05
#    ------------------------ --------------- 23.4/38.1 MB 3.5 MB/s eta 0:00:05
#    ------------------------ --------------- 23.5/38.1 MB 3.6 MB/s eta 0:00:05
#    ------------------------ --------------- 23.7/38.1 MB 3.6 MB/s eta 0:00:05
#    ------------------------- -------------- 23.9/38.1 MB 3.6 MB/s eta 0:00:04
#    ------------------------- -------------- 24.1/38.1 MB 3.6 MB/s eta 0:00:04
#    ------------------------- -------------- 24.3/38.1 MB 3.6 MB/s eta 0:00:04
#    ------------------------- -------------- 24.5/38.1 MB 3.7 MB/s eta 0:00:04
#    -------------------------- ------------- 24.8/38.1 MB 3.7 MB/s eta 0:00:04
#    -------------------------- ------------- 25.0/38.1 MB 3.7 MB/s eta 0:00:04
#    -------------------------- ------------- 25.2/38.1 MB 3.7 MB/s eta 0:00:04
#    -------------------------- ------------- 25.5/38.1 MB 3.7 MB/s eta 0:00:04
#    -------------------------- ------------- 25.6/38.1 MB 3.7 MB/s eta 0:00:04
#    -------------------------- ------------- 25.6/38.1 MB 3.7 MB/s eta 0:00:04
#    -------------------------- ------------- 25.6/38.1 MB 3.7 MB/s eta 0:00:04
#    --------------------------- ------------ 25.8/38.1 MB 3.6 MB/s eta 0:00:04
#    --------------------------- ------------ 26.0/38.1 MB 3.6 MB/s eta 0:00:04
#    --------------------------- ------------ 26.1/38.1 MB 3.6 MB/s eta 0:00:04
#    --------------------------- ------------ 26.3/38.1 MB 3.5 MB/s eta 0:00:04
#    --------------------------- ------------ 26.5/38.1 MB 3.6 MB/s eta 0:00:04
#    ---------------------------- ----------- 26.7/38.1 MB 3.5 MB/s eta 0:00:04
#    ---------------------------- ----------- 26.9/38.1 MB 3.5 MB/s eta 0:00:04
#    ---------------------------- ----------- 27.1/38.1 MB 3.5 MB/s eta 0:00:04
#    ---------------------------- ----------- 27.3/38.1 MB 3.5 MB/s eta 0:00:04
#    ---------------------------- ----------- 27.5/38.1 MB 3.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 27.7/38.1 MB 3.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 27.9/38.1 MB 3.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 28.1/38.1 MB 3.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 28.3/38.1 MB 3.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 28.5/38.1 MB 3.5 MB/s eta 0:00:03
#    ------------------------------ --------- 28.7/38.1 MB 3.5 MB/s eta 0:00:03
#    ------------------------------ --------- 28.9/38.1 MB 3.5 MB/s eta 0:00:03
#    ------------------------------ --------- 29.1/38.1 MB 3.5 MB/s eta 0:00:03
#    ------------------------------ --------- 29.3/38.1 MB 3.5 MB/s eta 0:00:03
#    ------------------------------ --------- 29.5/38.1 MB 3.5 MB/s eta 0:00:03
#    ------------------------------- -------- 29.8/38.1 MB 3.4 MB/s eta 0:00:03
#    ------------------------------- -------- 30.0/38.1 MB 3.6 MB/s eta 0:00:03
#    ------------------------------- -------- 30.2/38.1 MB 3.6 MB/s eta 0:00:03
#    ------------------------------- -------- 30.4/38.1 MB 3.8 MB/s eta 0:00:03
#    -------------------------------- ------- 30.7/38.1 MB 3.8 MB/s eta 0:00:02
#    -------------------------------- ------- 30.9/38.1 MB 3.9 MB/s eta 0:00:02
#    -------------------------------- ------- 31.0/38.1 MB 3.9 MB/s eta 0:00:02
#    -------------------------------- ------- 31.0/38.1 MB 3.9 MB/s eta 0:00:02
#    -------------------------------- ------- 31.0/38.1 MB 3.9 MB/s eta 0:00:02
#    -------------------------------- ------- 31.2/38.1 MB 3.7 MB/s eta 0:00:02
#    --------------------------------- ------ 31.4/38.1 MB 3.7 MB/s eta 0:00:02
#    --------------------------------- ------ 31.6/38.1 MB 3.7 MB/s eta 0:00:02
#    --------------------------------- ------ 31.8/38.1 MB 3.7 MB/s eta 0:00:02
#    --------------------------------- ------ 32.1/38.1 MB 3.7 MB/s eta 0:00:02
#    --------------------------------- ------ 32.3/38.1 MB 3.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 32.5/38.1 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 32.7/38.1 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 32.9/38.1 MB 4.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.2/38.1 MB 4.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 33.4/38.1 MB 4.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 33.7/38.1 MB 4.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 33.9/38.1 MB 4.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 33.9/38.1 MB 4.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 33.9/38.1 MB 4.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.0/38.1 MB 3.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.2/38.1 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 34.4/38.1 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 34.6/38.1 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 34.8/38.1 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 34.9/38.1 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 34.9/38.1 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 34.9/38.1 MB 3.7 MB/s eta 0:00:01
#    ------------------------------------ --- 35.1/38.1 MB 3.7 MB/s eta 0:00:01
#    ------------------------------------- -- 35.2/38.1 MB 3.7 MB/s eta 0:00:01
#    ------------------------------------- -- 35.4/38.1 MB 3.7 MB/s eta 0:00:01
#    ------------------------------------- -- 35.5/38.1 MB 3.7 MB/s eta 0:00:01
#    ------------------------------------- -- 35.7/38.1 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------- -- 35.9/38.1 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------- -- 36.0/38.1 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 36.2/38.1 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 36.4/38.1 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 36.6/38.1 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 36.7/38.1 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 36.7/38.1 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 36.7/38.1 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 36.9/38.1 MB 3.6 MB/s eta 0:00:01
#    -------------------------------------- - 37.0/38.1 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  37.2/38.1 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  37.3/38.1 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  37.5/38.1 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  37.6/38.1 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  37.8/38.1 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  37.9/38.1 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  38.1/38.1 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 38.1/38.1 MB 3.5 MB/s eta 0:00:00
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.8.1.78

# %%
# Importing required libraries
import cv2
import numpy as np
from sklearn.decomposition import PCA

# %%
# Loading the image 
img = cv2.imread('img/my_doggo_sample.jpeg')
img
# Out:
# array([[[133, 163, 183],
#         [133, 163, 183],
#         [133, 163, 183],
#         ...,
#         [192, 216, 246],
#         [193, 217, 248],
#         [193, 217, 248]],
#
#        [[133, 163, 183],
#         [133, 163, 183],
#         [133, 163, 183],
#         ...,
#         [191, 215, 245],
#         [192, 216, 246],
#         [192, 216, 246]],
#
#        [[133, 163, 183],
#         [133, 163, 183],
#         [133, 163, 183],
#         ...,
#         [189, 213, 243],
#         [190, 214, 244],
#         [190, 214, 244]],
#
#        ...,
#
#        [[ 47,  63,  76],
#         [ 30,  45,  56],
#         [ 47,  63,  69],
#         ...,
#         [ 26,  51,  77],
#         [ 29,  55,  79],
#         [ 50,  76, 100]],
#
#        [[ 46,  62,  75],
#         [ 18,  35,  46],
#         [ 29,  45,  52],
#         ...,
#         [ 40,  67,  95],
#         [ 40,  68,  93],
#         [ 48,  77, 100]],
#
#        [[ 32,  48,  61],
#         [ 17,  34,  45],
#         [ 20,  36,  42],
#         ...,
#         [ 47,  74, 102],
#         [ 43,  73,  98],
#         [ 48,  79, 103]]], dtype=uint8)

# %%
img
# Out:
# array([[[133, 163, 183],
#         [133, 163, 183],
#         [133, 163, 183],
#         ...,
#         [192, 216, 246],
#         [193, 217, 248],
#         [193, 217, 248]],
#
#        [[133, 163, 183],
#         [133, 163, 183],
#         [133, 163, 183],
#         ...,
#         [191, 215, 245],
#         [192, 216, 246],
#         [192, 216, 246]],
#
#        [[133, 163, 183],
#         [133, 163, 183],
#         [133, 163, 183],
#         ...,
#         [189, 213, 243],
#         [190, 214, 244],
#         [190, 214, 244]],
#
#        ...,
#
#        [[ 47,  63,  76],
#         [ 30,  45,  56],
#         [ 47,  63,  69],
#         ...,
#         [ 26,  51,  77],
#         [ 29,  55,  79],
#         [ 50,  76, 100]],
#
#        [[ 46,  62,  75],
#         [ 18,  35,  46],
#         [ 29,  45,  52],
#         ...,
#         [ 40,  67,  95],
#         [ 40,  68,  93],
#         [ 48,  77, 100]],
#
#        [[ 32,  48,  61],
#         [ 17,  34,  45],
#         [ 20,  36,  42],
#         ...,
#         [ 47,  74, 102],
#         [ 43,  73,  98],
#         [ 48,  79, 103]]], dtype=uint8)

# %%
plt.imshow(img);

# %%
rgb_image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image);

# %%
img.shape
# Out:
# (793, 1280, 3)

# %%
img.size
# Out:
# 3045120

# %%
793*1280
# Out:
# 1015040

# %%
img
# Out:
# array([[[133, 163, 183],
#         [133, 163, 183],
#         [133, 163, 183],
#         ...,
#         [192, 216, 246],
#         [193, 217, 248],
#         [193, 217, 248]],
#
#        [[133, 163, 183],
#         [133, 163, 183],
#         [133, 163, 183],
#         ...,
#         [191, 215, 245],
#         [192, 216, 246],
#         [192, 216, 246]],
#
#        [[133, 163, 183],
#         [133, 163, 183],
#         [133, 163, 183],
#         ...,
#         [189, 213, 243],
#         [190, 214, 244],
#         [190, 214, 244]],
#
#        ...,
#
#        [[ 47,  63,  76],
#         [ 30,  45,  56],
#         [ 47,  63,  69],
#         ...,
#         [ 26,  51,  77],
#         [ 29,  55,  79],
#         [ 50,  76, 100]],
#
#        [[ 46,  62,  75],
#         [ 18,  35,  46],
#         [ 29,  45,  52],
#         ...,
#         [ 40,  67,  95],
#         [ 40,  68,  93],
#         [ 48,  77, 100]],
#
#        [[ 32,  48,  61],
#         [ 17,  34,  45],
#         [ 20,  36,  42],
#         ...,
#         [ 47,  74, 102],
#         [ 43,  73,  98],
#         [ 48,  79, 103]]], dtype=uint8)

# %%
# Splitting the image in R,G,B arrays.
blue, green, red = cv2.split(img)

#it will split the original image into Blue, Green and Red arrays.

# %%
blue.shape
# Out:
# (793, 1280)

# %%
img_not_compressed = cv2.merge([red,green,blue])
#viewing the not compressed image
plt.imshow(img_not_compressed);

# %%
img_not_compressed = cv2.merge([blue, green, red])
#viewing the not compressed image
plt.imshow(img_not_compressed);

# %% [markdown]
# OpenCV will split into Blue, Green, and Red channels instead of Red, Blue, and Green. Be very careful of the sequence here.

# %%
# Initialize PCA with first 20 principal components
pca = PCA(20)
 
#Applying to red channel and then applying inverse transform to transformed array.
red_transformed = pca.fit_transform(red)
print('red_transformed.shape:', red_transformed.shape)
red_inverted = pca.inverse_transform(red_transformed)
print('red_inverted.shape:', red_inverted.shape)

#Applying to Green channel and then applying inverse transform to transformed array.
green_transformed = pca.fit_transform(green)
print('green_transformed.shape:', green_transformed.shape)
green_inverted = pca.inverse_transform(green_transformed)
print('green_inverted.shape:', green_inverted.shape)
 
#Applying to Blue channel and then applying inverse transform to transformed array.
blue_transformed = pca.fit_transform(blue)
print('blue_transformed.shape:', blue_transformed.shape)
blue_inverted = pca.inverse_transform(blue_transformed)
print('blue_inverted.shape:', blue_inverted.shape)
# Out:
# red_transformed.shape: (793, 20)
# red_inverted.shape: (793, 1280)
# green_transformed.shape: (793, 20)
# green_inverted.shape: (793, 1280)
# blue_transformed.shape: (793, 20)
# blue_inverted.shape: (793, 1280)

# %% [markdown]
# In the process of reconstructing the original dimensions from the reduced dimensions, some information is lost as we keep only selected principal components, 20 in this case.

# %%
img_compressed = (cv2.merge([red_inverted, green_inverted, blue_inverted])).astype(np.uint8)

# %% [markdown]
# Stacking the inverted arrays using dstack function. Here it is important to specify the datatype of our arrays, as most images are of 8 bit. Each pixel is represented by one 8-bit byte.

# %%
#viewing the compressed image
plt.imshow(img_compressed)
# plt.imsave('img\img_compressed.jpg', img_compressed);

# %% [markdown]
# The output above is what we get when considering just 20 Principal components.
#
# If we increase the number of Principal components the output image will get clear.

# %% [markdown]
# 1) Now check with how many Principal Components your eyes can't see the difference with the original!

# %% [markdown]
# 2) The dog should not be so blue, fix it!

# %%
# Initialize PCA with first 20 principal components
pca = PCA(300)
 
#Applying to red channel and then applying inverse transform to transformed array.
red_transformed = pca.fit_transform(red)
print('red_transformed.shape:', red_transformed.shape)
red_inverted = pca.inverse_transform(red_transformed)
print('red_inverted.shape:', red_inverted.shape)

#Applying to Green channel and then applying inverse transform to transformed array.
green_transformed = pca.fit_transform(green)
print('green_transformed.shape:', green_transformed.shape)
green_inverted = pca.inverse_transform(green_transformed)
print('green_inverted.shape:', green_inverted.shape)
 
#Applying to Blue channel and then applying inverse transform to transformed array.
blue_transformed = pca.fit_transform(blue)
print('blue_transformed.shape:', blue_transformed.shape)
blue_inverted = pca.inverse_transform(blue_transformed)
print('blue_inverted.shape:', blue_inverted.shape)

img_compressed = (cv2.merge([red_inverted, green_inverted, blue_inverted])).astype(np.uint8)

#viewing the compressed image
plt.imshow(img_compressed);
# Out:
# red_transformed.shape: (793, 300)
# red_inverted.shape: (793, 1280)
# green_transformed.shape: (793, 300)
# green_inverted.shape: (793, 1280)
# blue_transformed.shape: (793, 300)
# blue_inverted.shape: (793, 1280)

# %%
pca.explained_variance_ratio_.cumsum()
# Out:
# array([0.71914516, 0.84908078, 0.87286237, 0.88844408, 0.89865226,
#        0.90765092, 0.91383793, 0.91975685, 0.9250571 , 0.9297264 ,
#        0.933692  , 0.93751202, 0.94103888, 0.94404696, 0.94677529,
#        0.94935898, 0.95170765, 0.95398267, 0.95603986, 0.9579354 ,
#        0.95980251, 0.96157869, 0.96316876, 0.96467165, 0.96613913,
#        0.96749861, 0.96879963, 0.97007384, 0.97123758, 0.97233711,
#        0.97340584, 0.974405  , 0.97537922, 0.97628754, 0.97715436,
#        0.97796994, 0.97875348, 0.97952903, 0.98026559, 0.98095624,
#        0.98161481, 0.98224925, 0.98284966, 0.98343271, 0.98398928,
#        0.98450207, 0.98499793, 0.98547484, 0.98593405, 0.98637935,
#        0.9868111 , 0.98723624, 0.98763407, 0.98802932, 0.98839627,
#        0.98875005, 0.98909782, 0.9894282 , 0.98973969, 0.99004701,
#        0.99034098, 0.99062507, 0.9909028 , 0.99117515, 0.99143564,
#        0.99168259, 0.99192426, 0.99215462, 0.99237763, 0.99259952,
#        0.992815  , 0.99301592, 0.99320767, 0.9933938 , 0.99357467,
#        0.99374872, 0.99392066, 0.99408806, 0.99424893, 0.99440452,
#        0.99455727, 0.99469999, 0.99483446, 0.9949653 , 0.99509131,
#        0.99521081, 0.99532973, 0.99544654, 0.99556   , 0.99566995,
#        0.99577414, 0.99587718, 0.99597968, 0.99607824, 0.99617406,
#        0.9962667 , 0.99635683, 0.9964427 , 0.99652704, 0.99660939,
#        0.99668778, 0.99676343, 0.99683707, 0.99690612, 0.99697329,
